# %% [markdown]
# # Trabalho Pratico 4 - Aprendizagem de Maquina
# Nome: Rafael Zardo Crevelari
# Matrícula: ES105468

# %% [markdown]
# # Dependências Externas
#
# Antes de prosseguir com a implementação, é necessário executar as células a seguir para instalar as dependências externas necessárias

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Recursos Auxiliares
# Antes de prosseguir com a implementação, é importante executar a célula a seguir para declarar as variáveis e recursos necessários que serão utilizados ao longo do código. Essa etapa é fundamental para garantir que todas as dependências estejam corretamente definidas e disponíveis para serem utilizadas no restante do código. Certifique-se de executar essa célula antes de continuar com a implementação.

# %%
# Import de bibliotecas que serao usadas nos experimentos
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn import svm
from sklearn import neighbors
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Recursos de estilizacao
STYLE = "crest" # Style padrao para todos recursos de estilizacao
plt.style.use('bmh') # Style padrao para todos recursos do plt

# Componentes globais dos experimentos
melhoresAcuracias = [None, None, None, None, None, None, None] # Armazena a melhor acuracia obitida em cada experimento
metodosTestados = ["NB", "DT", "SVML", "SVMR", "k-NN", "RF", "GTB"] # Armazena as abreviações dos métodos testados

# %% [markdown]
# # Dataframe
# Antes de continuar com a implementação, é necessário carregar o arquivo "koi_data.csv". Certifique-se de que o arquivo esteja localizado na mesma pasta deste notebook para que o dataframe possa ser carregado corretamente.

# %%
# Coleta o dataframde do arquivo
dataframePrincipal = pd.read_csv('koi_data.csv')

# Separa os dataframes
# features = dataframePrincipal.drop(['kepoi_name','koi_disposition'],axis=1)
# targets = dataframePrincipal['koi_disposition']

#features = dataframeFeatures # X
#targets = dataframeTarget # Y

X = dataframePrincipal.drop(['kepoi_name','koi_disposition'],axis=1)
y = dataframePrincipal['koi_disposition']

# %% [markdown]
# # Treino com Dataframe
# Antes de avançar com a implementação, é necessário criar as variáveis de treinamento e teste para as features e targets. Essas variáveis serão usadas posteriormente no processo de treinamento e avaliação do modelo. Certifique-se de preparar corretamente essas variáveis antes de prosseguir.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
#featuresTrain, featuresTest, targetsTrain, targetsTest = train_test_split(features, targets, test_size=0.5, random_state=0)

# %% [markdown]
# # Naive Bayes (NB)

# %%
gnb = GaussianNB()

y_fit = gnb.fit(X_train, y_train)
y_pred = y_fit.predict(X_test)

resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda

acuracia = accuracy_score(y_test, y_pred)
validacaoCruzada = cross_val_score(gnb, X_train, y_train, cv=5)

melhoresAcuracias[0] = acuracia

# %% [markdown]
# ## Gráficos de Resultados
# Os testes realizados utilizando o método Naive Bayes nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
dfResumoClassificacaoEstilizada = dfResumoClassificacao.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Classificação:")
display(dfResumoClassificacaoEstilizada)
# Out:
# Resumo da Classificação:
# <style type="text/css">
# #T_db11d_row0_col0, #T_db11d_row0_col2, #T_db11d_row1_col1, #T_db11d_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_db11d_row0_col1, #T_db11d_row1_col0, #T_db11d_row1_col2, #T_db11d_row3_col3, #T_db11d_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_db11d_row0_col3, #T_db11d_row2_col1, #T_db11d_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_db11d_row1_col3, #T_db11d_row4_col0, #T_db11d_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_db11d_row2_col0 {
#   background-color: #43938f;
#   color: #f1f1f1;
# }
# #T_db11d_row2_col2, #T_db11d_row3_col0, #T_db11d_row3_col1, #T_db11d_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db11d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db11d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_db11d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_db11d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_db11d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db11d_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_db11d_row0_col0" class="data row0 col0" >0.663</td>
#       <td id="T_db11d_row0_col1" class="data row0 col1" >0.975</td>
#       <td id="T_db11d_row0_col2" class="data row0 col2" >0.789</td>
#       <td id="T_db11d_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_db11d_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_db11d_row1_col0" class="data row1 col0" >0.975</td>
#       <td id="T_db11d_row1_col1" class="data row1 col1" >0.666</td>
#       <td id="T_db11d_row1_col2" class="data row1 col2" >0.792</td>
#       <td id="T_db11d_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_db11d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_db11d_row2_col0" class="data row2 col0" >0.790</td>
#       <td id="T_db11d_row2_col1" class="data row2 col1" >0.790</td>
#       <td id="T_db11d_row2_col2" class="data row2 col2" >0.790</td>
#       <td id="T_db11d_row2_col3" class="data row2 col3" >0.790</td>
#     </tr>
#     <tr>
#       <th id="T_db11d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_db11d_row3_col0" class="data row3 col0" >0.819</td>
#       <td id="T_db11d_row3_col1" class="data row3 col1" >0.821</td>
#       <td id="T_db11d_row3_col2" class="data row3 col2" >0.790</td>
#       <td id="T_db11d_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_db11d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_db11d_row4_col0" class="data row4 col0" >0.850</td>
#       <td id="T_db11d_row4_col1" class="data row4 col1" >0.790</td>
#       <td id="T_db11d_row4_col2" class="data row4 col2" >0.791</td>
#       <td id="T_db11d_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matriz de Confusão

# %%
# Obtem a matriz de confusão
confusionMatrix = confusion_matrix(y_test, y_pred)

# Desenha a matriz de confusão
plt.figure(figsize=(3, 3))
sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
plt.title('Matriz de Confusão')
plt.xlabel('Rótulo Falso Verdadeiro')
plt.ylabel('Rótulo Verdadeiro')
plt.grid(False)
plt.show()

totalRotulos = X_test.shape[0]
corretamenteRotulados = (y_test == y_pred).sum()
incorretamenteRotulados = (y_test != y_pred).sum()

print("Número de pontos corretamente rotulados de um total de", totalRotulos, "pontos:", corretamenteRotulados, "(", round((corretamenteRotulados / totalRotulos) * 100), "%)")
print("Número de pontos incorretamente rotulados de um total de", totalRotulos, "pontos:", incorretamenteRotulados, "(", round((incorretamenteRotulados / totalRotulos) * 100), "%) \n")
# Out:
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2056 ( 79 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 545 ( 21 %)

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold

# %%
dfResultadosAcuracia = pd.DataFrame({
    'Acurácia': [acuracia]
})

dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada': validacaoCruzada  
})

dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Acurácia e Validação Cruzada (k=5)")
display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# Resumo da Acurácia e Validação Cruzada (k=5)
# <style type="text/css">
# #T_2b112_row0_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# </style>
# <table id="T_2b112">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b112_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b112_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b112_row0_col0" class="data row0 col0" >0.790</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_db24d_row0_col0 {
#   background-color: #49998f;
#   color: #f1f1f1;
# }
# #T_db24d_row1_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_db24d_row2_col0 {
#   background-color: #6ab090;
#   color: #f1f1f1;
# }
# #T_db24d_row3_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_db24d_row4_col0 {
#   background-color: #4b9b90;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db24d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db24d_level0_col0" class="col_heading level0 col0" >Validação Cruzada</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db24d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db24d_row0_col0" class="data row0 col0" >0.812</td>
#     </tr>
#     <tr>
#       <th id="T_db24d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db24d_row1_col0" class="data row1 col0" >0.829</td>
#     </tr>
#     <tr>
#       <th id="T_db24d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db24d_row2_col0" class="data row2 col0" >0.808</td>
#     </tr>
#     <tr>
#       <th id="T_db24d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db24d_row3_col0" class="data row3 col0" >0.802</td>
#     </tr>
#     <tr>
#       <th id="T_db24d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db24d_row4_col0" class="data row4 col0" >0.812</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inferência Sobre os Resultados

# %% [markdown]
# # Decision Tree (DT)

# %%
tamanhosMaximosArvore = [10, 20, 30, 40, 50, 60, 70, "INFINITO"]
y_fits = []
y_preds = []
dfResumosClassificacao = []
acuracias = []
validacoesCruzadas = []

for tamanhoMaximoArvore in tamanhosMaximosArvore:

    if (tamanhoMaximoArvore != "INFINITO"):
        clf = tree.DecisionTreeClassifier(max_depth=tamanhoMaximoArvore)
    else:
        clf = tree.DecisionTreeClassifier(max_depth=None)

    y_fit = clf.fit(X_train, y_train)
    y_fits.append(y_fit)
    
    y_pred = y_fit.predict(X_test)
    y_preds.append(y_pred)

    resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
    dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda
    dfResumosClassificacao.append(dfResumoClassificacao)
    
    acuracia = accuracy_score(y_test, y_pred)
    acuracias.append(acuracia)
    
    validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)
    validacoesCruzadas.append(validacaoCruzada)
    
melhoresAcuracias[1] = acuracia

# %% [markdown]
# ## Gráficos de Resultados

# %% [markdown]
# Os testes realizados utilizando o método Decision Tree nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
for i in range(len(dfResumosClassificacao)):
    dfResumoClassificacaoEstilizada = dfResumosClassificacao[i].style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

    print("Resumo da classificação para arvore de tamanho maximo", tamanhosMaximosArvore[i])
    display(dfResumoClassificacaoEstilizada)
# Out:
# Resumo da classificação para arvore de tamanho maximo 10
# <style type="text/css">
# #T_9bebe_row0_col0, #T_9bebe_row0_col2, #T_9bebe_row1_col1, #T_9bebe_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_9bebe_row0_col1, #T_9bebe_row1_col0, #T_9bebe_row1_col2, #T_9bebe_row3_col3, #T_9bebe_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_9bebe_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_9bebe_row1_col3, #T_9bebe_row4_col0, #T_9bebe_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_9bebe_row2_col0 {
#   background-color: #26788c;
#   color: #f1f1f1;
# }
# #T_9bebe_row2_col1, #T_9bebe_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_9bebe_row2_col2 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_9bebe_row3_col0, #T_9bebe_row3_col1, #T_9bebe_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9bebe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bebe_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_9bebe_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_9bebe_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_9bebe_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bebe_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_9bebe_row0_col0" class="data row0 col0" >0.913</td>
#       <td id="T_9bebe_row0_col1" class="data row0 col1" >0.945</td>
#       <td id="T_9bebe_row0_col2" class="data row0 col2" >0.929</td>
#       <td id="T_9bebe_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_9bebe_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_9bebe_row1_col0" class="data row1 col0" >0.962</td>
#       <td id="T_9bebe_row1_col1" class="data row1 col1" >0.940</td>
#       <td id="T_9bebe_row1_col2" class="data row1 col2" >0.951</td>
#       <td id="T_9bebe_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_9bebe_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_9bebe_row2_col0" class="data row2 col0" >0.942</td>
#       <td id="T_9bebe_row2_col1" class="data row2 col1" >0.942</td>
#       <td id="T_9bebe_row2_col2" class="data row2 col2" >0.942</td>
#       <td id="T_9bebe_row2_col3" class="data row2 col3" >0.942</td>
#     </tr>
#     <tr>
#       <th id="T_9bebe_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_9bebe_row3_col0" class="data row3 col0" >0.937</td>
#       <td id="T_9bebe_row3_col1" class="data row3 col1" >0.942</td>
#       <td id="T_9bebe_row3_col2" class="data row3 col2" >0.940</td>
#       <td id="T_9bebe_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_9bebe_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_9bebe_row4_col0" class="data row4 col0" >0.942</td>
#       <td id="T_9bebe_row4_col1" class="data row4 col1" >0.942</td>
#       <td id="T_9bebe_row4_col2" class="data row4 col2" >0.942</td>
#       <td id="T_9bebe_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 20
# <style type="text/css">
# #T_5a847_row0_col0, #T_5a847_row0_col1, #T_5a847_row0_col2, #T_5a847_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_5a847_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_5a847_row1_col0, #T_5a847_row1_col1, #T_5a847_row1_col2, #T_5a847_row3_col3, #T_5a847_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_5a847_row1_col3, #T_5a847_row2_col1, #T_5a847_row4_col0, #T_5a847_row4_col1, #T_5a847_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_5a847_row2_col0 {
#   background-color: #26788c;
#   color: #f1f1f1;
# }
# #T_5a847_row2_col2 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_5a847_row3_col0, #T_5a847_row3_col1 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_5a847_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a847">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a847_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_5a847_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_5a847_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_5a847_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a847_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_5a847_row0_col0" class="data row0 col0" >0.909</td>
#       <td id="T_5a847_row0_col1" class="data row0 col1" >0.936</td>
#       <td id="T_5a847_row0_col2" class="data row0 col2" >0.922</td>
#       <td id="T_5a847_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_5a847_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_5a847_row1_col0" class="data row1 col0" >0.956</td>
#       <td id="T_5a847_row1_col1" class="data row1 col1" >0.937</td>
#       <td id="T_5a847_row1_col2" class="data row1 col2" >0.946</td>
#       <td id="T_5a847_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_5a847_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_5a847_row2_col0" class="data row2 col0" >0.937</td>
#       <td id="T_5a847_row2_col1" class="data row2 col1" >0.937</td>
#       <td id="T_5a847_row2_col2" class="data row2 col2" >0.937</td>
#       <td id="T_5a847_row2_col3" class="data row2 col3" >0.937</td>
#     </tr>
#     <tr>
#       <th id="T_5a847_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_5a847_row3_col0" class="data row3 col0" >0.933</td>
#       <td id="T_5a847_row3_col1" class="data row3 col1" >0.936</td>
#       <td id="T_5a847_row3_col2" class="data row3 col2" >0.934</td>
#       <td id="T_5a847_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_5a847_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_5a847_row4_col0" class="data row4 col0" >0.937</td>
#       <td id="T_5a847_row4_col1" class="data row4 col1" >0.937</td>
#       <td id="T_5a847_row4_col2" class="data row4 col2" >0.937</td>
#       <td id="T_5a847_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 30
# <style type="text/css">
# #T_a284f_row0_col0, #T_a284f_row0_col1, #T_a284f_row0_col2, #T_a284f_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_a284f_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_a284f_row1_col0, #T_a284f_row1_col1, #T_a284f_row1_col2, #T_a284f_row3_col3, #T_a284f_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_a284f_row1_col3, #T_a284f_row2_col1, #T_a284f_row2_col2, #T_a284f_row4_col0, #T_a284f_row4_col1, #T_a284f_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_a284f_row2_col0 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_a284f_row3_col0, #T_a284f_row3_col1, #T_a284f_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a284f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a284f_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a284f_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a284f_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a284f_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a284f_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_a284f_row0_col0" class="data row0 col0" >0.920</td>
#       <td id="T_a284f_row0_col1" class="data row0 col1" >0.929</td>
#       <td id="T_a284f_row0_col2" class="data row0 col2" >0.924</td>
#       <td id="T_a284f_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_a284f_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_a284f_row1_col0" class="data row1 col0" >0.952</td>
#       <td id="T_a284f_row1_col1" class="data row1 col1" >0.945</td>
#       <td id="T_a284f_row1_col2" class="data row1 col2" >0.949</td>
#       <td id="T_a284f_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_a284f_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a284f_row2_col0" class="data row2 col0" >0.939</td>
#       <td id="T_a284f_row2_col1" class="data row2 col1" >0.939</td>
#       <td id="T_a284f_row2_col2" class="data row2 col2" >0.939</td>
#       <td id="T_a284f_row2_col3" class="data row2 col3" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_a284f_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a284f_row3_col0" class="data row3 col0" >0.936</td>
#       <td id="T_a284f_row3_col1" class="data row3 col1" >0.937</td>
#       <td id="T_a284f_row3_col2" class="data row3 col2" >0.937</td>
#       <td id="T_a284f_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_a284f_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a284f_row4_col0" class="data row4 col0" >0.939</td>
#       <td id="T_a284f_row4_col1" class="data row4 col1" >0.939</td>
#       <td id="T_a284f_row4_col2" class="data row4 col2" >0.939</td>
#       <td id="T_a284f_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 40
# <style type="text/css">
# #T_72e95_row0_col0, #T_72e95_row0_col1, #T_72e95_row0_col2, #T_72e95_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_72e95_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_72e95_row1_col0, #T_72e95_row1_col1, #T_72e95_row1_col2, #T_72e95_row3_col3, #T_72e95_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_72e95_row1_col3, #T_72e95_row2_col1, #T_72e95_row4_col0, #T_72e95_row4_col1, #T_72e95_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_72e95_row2_col0, #T_72e95_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_72e95_row3_col0, #T_72e95_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_72e95_row3_col1 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72e95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72e95_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_72e95_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_72e95_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_72e95_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72e95_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_72e95_row0_col0" class="data row0 col0" >0.924</td>
#       <td id="T_72e95_row0_col1" class="data row0 col1" >0.923</td>
#       <td id="T_72e95_row0_col2" class="data row0 col2" >0.924</td>
#       <td id="T_72e95_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_72e95_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_72e95_row1_col0" class="data row1 col0" >0.948</td>
#       <td id="T_72e95_row1_col1" class="data row1 col1" >0.949</td>
#       <td id="T_72e95_row1_col2" class="data row1 col2" >0.949</td>
#       <td id="T_72e95_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_72e95_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_72e95_row2_col0" class="data row2 col0" >0.938</td>
#       <td id="T_72e95_row2_col1" class="data row2 col1" >0.938</td>
#       <td id="T_72e95_row2_col2" class="data row2 col2" >0.938</td>
#       <td id="T_72e95_row2_col3" class="data row2 col3" >0.938</td>
#     </tr>
#     <tr>
#       <th id="T_72e95_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_72e95_row3_col0" class="data row3 col0" >0.936</td>
#       <td id="T_72e95_row3_col1" class="data row3 col1" >0.936</td>
#       <td id="T_72e95_row3_col2" class="data row3 col2" >0.936</td>
#       <td id="T_72e95_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_72e95_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_72e95_row4_col0" class="data row4 col0" >0.938</td>
#       <td id="T_72e95_row4_col1" class="data row4 col1" >0.938</td>
#       <td id="T_72e95_row4_col2" class="data row4 col2" >0.938</td>
#       <td id="T_72e95_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 50
# <style type="text/css">
# #T_0f3ae_row0_col0, #T_0f3ae_row0_col1, #T_0f3ae_row0_col2, #T_0f3ae_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_0f3ae_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_0f3ae_row1_col0, #T_0f3ae_row1_col1, #T_0f3ae_row1_col2, #T_0f3ae_row3_col3, #T_0f3ae_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_0f3ae_row1_col3, #T_0f3ae_row2_col1, #T_0f3ae_row4_col0, #T_0f3ae_row4_col1, #T_0f3ae_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_0f3ae_row2_col0, #T_0f3ae_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_0f3ae_row3_col0, #T_0f3ae_row3_col1 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_0f3ae_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f3ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f3ae_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0f3ae_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0f3ae_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0f3ae_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f3ae_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_0f3ae_row0_col0" class="data row0 col0" >0.932</td>
#       <td id="T_0f3ae_row0_col1" class="data row0 col1" >0.929</td>
#       <td id="T_0f3ae_row0_col2" class="data row0 col2" >0.931</td>
#       <td id="T_0f3ae_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_0f3ae_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_0f3ae_row1_col0" class="data row1 col0" >0.952</td>
#       <td id="T_0f3ae_row1_col1" class="data row1 col1" >0.954</td>
#       <td id="T_0f3ae_row1_col2" class="data row1 col2" >0.953</td>
#       <td id="T_0f3ae_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_0f3ae_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_0f3ae_row2_col0" class="data row2 col0" >0.944</td>
#       <td id="T_0f3ae_row2_col1" class="data row2 col1" >0.944</td>
#       <td id="T_0f3ae_row2_col2" class="data row2 col2" >0.944</td>
#       <td id="T_0f3ae_row2_col3" class="data row2 col3" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_0f3ae_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_0f3ae_row3_col0" class="data row3 col0" >0.942</td>
#       <td id="T_0f3ae_row3_col1" class="data row3 col1" >0.942</td>
#       <td id="T_0f3ae_row3_col2" class="data row3 col2" >0.942</td>
#       <td id="T_0f3ae_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_0f3ae_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_0f3ae_row4_col0" class="data row4 col0" >0.944</td>
#       <td id="T_0f3ae_row4_col1" class="data row4 col1" >0.944</td>
#       <td id="T_0f3ae_row4_col2" class="data row4 col2" >0.944</td>
#       <td id="T_0f3ae_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 60
# <style type="text/css">
# #T_cf4dd_row0_col0, #T_cf4dd_row0_col1, #T_cf4dd_row0_col2, #T_cf4dd_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_cf4dd_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_cf4dd_row1_col0, #T_cf4dd_row1_col1, #T_cf4dd_row1_col2, #T_cf4dd_row3_col3, #T_cf4dd_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_cf4dd_row1_col3, #T_cf4dd_row2_col1, #T_cf4dd_row2_col2, #T_cf4dd_row4_col0, #T_cf4dd_row4_col1, #T_cf4dd_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_cf4dd_row2_col0 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_cf4dd_row3_col0, #T_cf4dd_row3_col1, #T_cf4dd_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf4dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf4dd_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_cf4dd_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_cf4dd_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_cf4dd_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf4dd_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_cf4dd_row0_col0" class="data row0 col0" >0.922</td>
#       <td id="T_cf4dd_row0_col1" class="data row0 col1" >0.931</td>
#       <td id="T_cf4dd_row0_col2" class="data row0 col2" >0.926</td>
#       <td id="T_cf4dd_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_cf4dd_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_cf4dd_row1_col0" class="data row1 col0" >0.953</td>
#       <td id="T_cf4dd_row1_col1" class="data row1 col1" >0.947</td>
#       <td id="T_cf4dd_row1_col2" class="data row1 col2" >0.950</td>
#       <td id="T_cf4dd_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_cf4dd_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_cf4dd_row2_col0" class="data row2 col0" >0.940</td>
#       <td id="T_cf4dd_row2_col1" class="data row2 col1" >0.940</td>
#       <td id="T_cf4dd_row2_col2" class="data row2 col2" >0.940</td>
#       <td id="T_cf4dd_row2_col3" class="data row2 col3" >0.940</td>
#     </tr>
#     <tr>
#       <th id="T_cf4dd_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_cf4dd_row3_col0" class="data row3 col0" >0.937</td>
#       <td id="T_cf4dd_row3_col1" class="data row3 col1" >0.939</td>
#       <td id="T_cf4dd_row3_col2" class="data row3 col2" >0.938</td>
#       <td id="T_cf4dd_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_cf4dd_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_cf4dd_row4_col0" class="data row4 col0" >0.941</td>
#       <td id="T_cf4dd_row4_col1" class="data row4 col1" >0.940</td>
#       <td id="T_cf4dd_row4_col2" class="data row4 col2" >0.940</td>
#       <td id="T_cf4dd_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo 70
# <style type="text/css">
# #T_a5656_row0_col0, #T_a5656_row0_col1, #T_a5656_row0_col2, #T_a5656_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_a5656_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_a5656_row1_col0, #T_a5656_row1_col1, #T_a5656_row1_col2, #T_a5656_row3_col3, #T_a5656_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_a5656_row1_col3, #T_a5656_row2_col0, #T_a5656_row2_col1, #T_a5656_row2_col2, #T_a5656_row4_col0, #T_a5656_row4_col1, #T_a5656_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_a5656_row3_col0 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_a5656_row3_col1, #T_a5656_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5656">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5656_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a5656_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a5656_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a5656_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5656_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_a5656_row0_col0" class="data row0 col0" >0.918</td>
#       <td id="T_a5656_row0_col1" class="data row0 col1" >0.921</td>
#       <td id="T_a5656_row0_col2" class="data row0 col2" >0.919</td>
#       <td id="T_a5656_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_a5656_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_a5656_row1_col0" class="data row1 col0" >0.946</td>
#       <td id="T_a5656_row1_col1" class="data row1 col1" >0.945</td>
#       <td id="T_a5656_row1_col2" class="data row1 col2" >0.946</td>
#       <td id="T_a5656_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_a5656_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a5656_row2_col0" class="data row2 col0" >0.935</td>
#       <td id="T_a5656_row2_col1" class="data row2 col1" >0.935</td>
#       <td id="T_a5656_row2_col2" class="data row2 col2" >0.935</td>
#       <td id="T_a5656_row2_col3" class="data row2 col3" >0.935</td>
#     </tr>
#     <tr>
#       <th id="T_a5656_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a5656_row3_col0" class="data row3 col0" >0.932</td>
#       <td id="T_a5656_row3_col1" class="data row3 col1" >0.933</td>
#       <td id="T_a5656_row3_col2" class="data row3 col2" >0.932</td>
#       <td id="T_a5656_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_a5656_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a5656_row4_col0" class="data row4 col0" >0.935</td>
#       <td id="T_a5656_row4_col1" class="data row4 col1" >0.935</td>
#       <td id="T_a5656_row4_col2" class="data row4 col2" >0.935</td>
#       <td id="T_a5656_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para arvore de tamanho maximo INFINITO
# <style type="text/css">
# #T_0512d_row0_col0, #T_0512d_row0_col1, #T_0512d_row0_col2, #T_0512d_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_0512d_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_0512d_row1_col0, #T_0512d_row1_col1, #T_0512d_row1_col2, #T_0512d_row3_col3, #T_0512d_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_0512d_row1_col3, #T_0512d_row2_col0, #T_0512d_row2_col1, #T_0512d_row2_col2, #T_0512d_row4_col0, #T_0512d_row4_col1, #T_0512d_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_0512d_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_0512d_row3_col1, #T_0512d_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0512d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0512d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0512d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0512d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0512d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0512d_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_0512d_row0_col0" class="data row0 col0" >0.921</td>
#       <td id="T_0512d_row0_col1" class="data row0 col1" >0.924</td>
#       <td id="T_0512d_row0_col2" class="data row0 col2" >0.922</td>
#       <td id="T_0512d_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_0512d_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_0512d_row1_col0" class="data row1 col0" >0.948</td>
#       <td id="T_0512d_row1_col1" class="data row1 col1" >0.947</td>
#       <td id="T_0512d_row1_col2" class="data row1 col2" >0.948</td>
#       <td id="T_0512d_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_0512d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_0512d_row2_col0" class="data row2 col0" >0.937</td>
#       <td id="T_0512d_row2_col1" class="data row2 col1" >0.937</td>
#       <td id="T_0512d_row2_col2" class="data row2 col2" >0.937</td>
#       <td id="T_0512d_row2_col3" class="data row2 col3" >0.937</td>
#     </tr>
#     <tr>
#       <th id="T_0512d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_0512d_row3_col0" class="data row3 col0" >0.935</td>
#       <td id="T_0512d_row3_col1" class="data row3 col1" >0.935</td>
#       <td id="T_0512d_row3_col2" class="data row3 col2" >0.935</td>
#       <td id="T_0512d_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_0512d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_0512d_row4_col0" class="data row4 col0" >0.937</td>
#       <td id="T_0512d_row4_col1" class="data row4 col1" >0.937</td>
#       <td id="T_0512d_row4_col2" class="data row4 col2" >0.937</td>
#       <td id="T_0512d_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matriz de Confusão

# %%
for i in range(len(dfResumosClassificacao)):
    print("Matriz de confusão para arvore de tamanho maximo", tamanhosMaximosArvore[i])
    
    # Obtem a matriz de confusão
    confusionMatrix = confusion_matrix(targetsTest, y_preds[i])

    # Desenha a matriz de confusão
    plt.figure(figsize=(3, 3))
    sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
    plt.title('Matriz de Confusão')
    plt.xlabel('Rótulo Falso Verdadeiro')
    plt.ylabel('Rótulo Verdadeiro')
    plt.grid(False)
    plt.show()

    totalRotulos = X_test.shape[0]
    corretamenteRotulados = (y_test == y_preds[i]).sum()
    incorretamenteRotulados = (y_test != y_preds[i]).sum()

    print("Número de pontos corretamente rotulados de um total de", totalRotulos, "pontos:", corretamenteRotulados, "(", round((corretamenteRotulados / totalRotulos) * 100), "%)")
    print("Número de pontos incorretamente rotulados de um total de", totalRotulos, "pontos:", incorretamenteRotulados, "(", round((incorretamenteRotulados / totalRotulos) * 100), "%) \n")
# Out:
# Matriz de confusão para arvore de tamanho maximo 10
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2449 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 152 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 20
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2436 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 165 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 30
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2442 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 159 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 40
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2441 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 160 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 50
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2456 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 145 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 60
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2446 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 155 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo 70
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2432 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 169 ( 6 %)
#
# Matriz de confusão para arvore de tamanho maximo INFINITO
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2438 ( 94 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 163 ( 6 %)

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold

# %%
dfResultadosAcuracia = pd.DataFrame({
'Acurácia': acuracias
}, index = tamanhosMaximosArvore)

mediasValidacoesCruzadas = [np.mean(k5Values) for k5Values in validacoesCruzadas]
dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada (média)': mediasValidacoesCruzadas
}, index = tamanhosMaximosArvore)


dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# <style type="text/css">
# #T_5a7b8_row0_col0 {
#   background-color: #1c6488;
#   color: #f1f1f1;
# }
# #T_5a7b8_row1_col0 {
#   background-color: #76b791;
#   color: #f1f1f1;
# }
# #T_5a7b8_row2_col0 {
#   background-color: #41928f;
#   color: #f1f1f1;
# }
# #T_5a7b8_row3_col0 {
#   background-color: #49988f;
#   color: #f1f1f1;
# }
# #T_5a7b8_row4_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_5a7b8_row5_col0 {
#   background-color: #26788c;
#   color: #f1f1f1;
# }
# #T_5a7b8_row6_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_5a7b8_row7_col0 {
#   background-color: #61aa90;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a7b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a7b8_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a7b8_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_5a7b8_row0_col0" class="data row0 col0" >0.942</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_5a7b8_row1_col0" class="data row1 col0" >0.937</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_5a7b8_row2_col0" class="data row2 col0" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_5a7b8_row3_col0" class="data row3 col0" >0.938</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_5a7b8_row4_col0" class="data row4 col0" >0.944</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_5a7b8_row5_col0" class="data row5 col0" >0.940</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_5a7b8_row6_col0" class="data row6 col0" >0.935</td>
#     </tr>
#     <tr>
#       <th id="T_5a7b8_level0_row7" class="row_heading level0 row7" >INFINITO</th>
#       <td id="T_5a7b8_row7_col0" class="data row7 col0" >0.937</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4a048_row0_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_4a048_row1_col0 {
#   background-color: #76b791;
#   color: #f1f1f1;
# }
# #T_4a048_row2_col0 {
#   background-color: #1f5985;
#   color: #f1f1f1;
# }
# #T_4a048_row3_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_4a048_row4_col0, #T_4a048_row6_col0 {
#   background-color: #509e90;
#   color: #f1f1f1;
# }
# #T_4a048_row5_col0 {
#   background-color: #1d6388;
#   color: #f1f1f1;
# }
# #T_4a048_row7_col0 {
#   background-color: #95c591;
#   color: #000000;
# }
# </style>
# <table id="T_4a048">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a048_level0_col0" class="col_heading level0 col0" >Validação Cruzada (média)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a048_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_4a048_row0_col0" class="data row0 col0" >0.941</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_4a048_row1_col0" class="data row1 col0" >0.935</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_4a048_row2_col0" class="data row2 col0" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_4a048_row3_col0" class="data row3 col0" >0.934</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_4a048_row4_col0" class="data row4 col0" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_4a048_row5_col0" class="data row5 col0" >0.939</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_4a048_row6_col0" class="data row6 col0" >0.936</td>
#     </tr>
#     <tr>
#       <th id="T_4a048_level0_row7" class="row_heading level0 row7" >INFINITO</th>
#       <td id="T_4a048_row7_col0" class="data row7 col0" >0.934</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparação da Acurácia e Validação Cruzada K-fold

# %%
plt.plot(tamanhosMaximosArvore, acuracias, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Acurácia')
plt.title('Variação da Acurácia em relação ao Número de Árvores')
plt.grid(False)
plt.show()

plt.plot(tamanhosMaximosArvore, validacoesCruzadas, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Validação Cruzada')
plt.title('Variação da Validação Cruzada em relação ao Número de Árvores')
plt.grid(False)
plt.show()

# %% [markdown]
# ## Inferência Sobre os Resultados

# %% [markdown]
# # SVM Linear (SVML)

# %%
clf = svm.SVC(kernel='linear')

y_fit = clf.fit(X_train, y_train)
y_pred = y_fit.predict(X_test)

resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda

acuracia = accuracy_score(y_test, y_pred)
validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)

melhoresAcuracias[2] = acuracia
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[130], line 3
#       1 clf = svm.SVC(kernel='linear')
# ----> 3 y_fit = clf.fit(X_train, y_train)
#       4 y_pred = y_fit.predict(X_test)
#       6 resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/svm/_base.py:252, in BaseLibSVM.fit(self, X, y, sample_weight)
#     249     print("[LibSVM]", end="")
#     251 seed = rnd.randint(np.iinfo("i").max)
# --> 252 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     253 # see comment on the other call to np.iinfo in this file
#     255 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/svm/_base.py:331, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     317 libsvm.set_verbosity_wrap(self.verbose)
#     319 # we don't pass **self.get_params() to allow subclasses to
#     320 # add other parameters to __init__
#     321 (
#     322     self.support_,
#     323     self.support_vectors_,
#     324     self._n_support,
#     325     self.dual_coef_,
#     326     self.intercept_,
#     327     self._probA,
#     328     self._probB,
#     329     self.fit_status_,
#     330     self._num_iter,
# --> 331 ) = libsvm.fit(
#     332     X,
#     333     y,
#     334     svm_type=solver_type,
#     335     sample_weight=sample_weight,
#     336     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     337     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     338     kernel=kernel,
#     339     C=self.C,
#     340     nu=self.nu,
#     341     probability=self.probability,
#     342     degree=self.degree,
#     343     shrinking=self.shrinking,
#     344     tol=self.tol,
#     345     cache_size=self.cache_size,
#     346     coef0=self.coef0,
#     347     gamma=self._gamma,
#     348     epsilon=self.epsilon,
#     349     max_iter=self.max_iter,
#     350     random_seed=random_seed,
#     351 )
#     353 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Gráficos Resultados

# %% [markdown]
# Os testes realizados utilizando o método SVM Linear nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
dfResumoClassificacaoEstilizada = dfResumoClassificacao.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Classificação:")
display(dfResumoClassificacaoEstilizada)

# %% [markdown]
# ### Matriz de Confusão

# %%
# Obtem a matriz de confusão
confusionMatrix = confusion_matrix(y_test, y_pred)

# Desenha a matriz de confusão
plt.figure(figsize=(3, 3))
sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
plt.title('Matriz de Confusão')
plt.xlabel('Rótulo Falso Verdadeiro')
plt.ylabel('Rótulo Verdadeiro')
plt.grid(False)
plt.show()

print("Número de pontos incorretamente rotulados de um total de ",X_test.shape[0]," pontos: ",(y_test != y_pred).sum())
# Out:
# Número de pontos incorretamente rotulados de um total de  2601  pontos:  160

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold

# %%
dfResultadosAcuracia = pd.DataFrame({
    'Acurácia': [acuracia]
})

dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada': validacaoCruzada  
})

dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Acurácia e Validação Cruzada (k=5)")
display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# Resumo da Acurácia e Validação Cruzada (k=5)
# <style type="text/css">
# #T_b027a_row0_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# </style>
# <table id="T_b027a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b027a_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b027a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b027a_row0_col0" class="data row0 col0" >0.938</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2119b_row0_col0 {
#   background-color: #1d6b8a;
#   color: #f1f1f1;
# }
# #T_2119b_row1_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_2119b_row2_col0 {
#   background-color: #509e90;
#   color: #f1f1f1;
# }
# #T_2119b_row3_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_2119b_row4_col0 {
#   background-color: #6db290;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2119b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2119b_level0_col0" class="col_heading level0 col0" >Validação Cruzada</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2119b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2119b_row0_col0" class="data row0 col0" >0.942</td>
#     </tr>
#     <tr>
#       <th id="T_2119b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2119b_row1_col0" class="data row1 col0" >0.952</td>
#     </tr>
#     <tr>
#       <th id="T_2119b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2119b_row2_col0" class="data row2 col0" >0.933</td>
#     </tr>
#     <tr>
#       <th id="T_2119b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2119b_row3_col0" class="data row3 col0" >0.923</td>
#     </tr>
#     <tr>
#       <th id="T_2119b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2119b_row4_col0" class="data row4 col0" >0.929</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inferência Sobre os Resultados

# %% [markdown]
# # SVM RBF (SVMR)

# %%
clf = svm.SVC(kernel='rbf')

y_fit = clf.fit(X_train, y_train)
y_pred = y_fit.predict(X_test)

resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda

acuracia = accuracy_score(y_test, y_pred)
validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)

melhoresAcuracias[3] = acuracia

# %% [markdown]
# ## Gráficos Resultados

# %% [markdown]
# Os testes realizados utilizando o método SVM RBF nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
dfResumoClassificacaoEstilizada = dfResumoClassificacao.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Classificação:")
display(dfResumoClassificacaoEstilizada)

# %% [markdown]
# ### Matriz de Confusão

# %%
# Obtem a matriz de confusão
confusionMatrix = confusion_matrix(y_test, y_pred)

# Desenha a matriz de confusão
plt.figure(figsize=(3, 3))
sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
plt.title('Matriz de Confusão')
plt.xlabel('Rótulo Falso Verdadeiro')
plt.ylabel('Rótulo Verdadeiro')
plt.grid(False)
plt.show()

print("Número de pontos incorretamente rotulados de um total de ",X_test.shape[0]," pontos: ",(y_test != y_pred).sum())

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold

# %%
dfResultadosAcuracia = pd.DataFrame({
    'Acurácia': [acuracia]
})

dfResultadosValidacaoCruzada = pd.DataFrame({
    'Validação Cruzada': validacaoCruzada  
})

dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Resumo da Acurácia e Validação Cruzada (k=5)")
display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)

# %% [markdown]
# ## Inferência Sobre os Resultados

# %% [markdown]
# # k-NN

# %%
numerosNeighbors = [10,20,30,40,50,60,70,80]
y_fits = []
y_preds = []
dfResumosClassificacao = []
acuracias = []
validacoesCruzadas = []

for numeroNeighbors in numerosNeighbors:

    clf = neighbors.KNeighborsClassifier(numeroNeighbors, weights='uniform')

    y_fit = clf.fit(X_train, y_train)
    y_fits.append(y_fit)
    
    y_pred = y_fit.predict(X_test)
    y_preds.append(y_pred)

    resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
    dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda
    dfResumosClassificacao.append(dfResumoClassificacao)
    
    acuracia = accuracy_score(y_test, y_pred)
    acuracias.append(acuracia)
    
    validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)
    validacoesCruzadas.append(validacaoCruzada)
    
melhoresAcuracias[4] = acuracia

# %% [markdown]
# ## Gráficos Resultados

# %% [markdown]
# Os testes realizados utilizando o método k-NN nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
for i in range(len(dfResumosClassificacao)):
    dfResumoClassificacaoEstilizada = dfResumosClassificacao[i].style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

    print("Resumo da classificação para numero de vizinhos igual a", numerosNeighbors[i])
    display(dfResumoClassificacaoEstilizada)
# Out:
# Resumo da classificação para numero de vizinhos igual a 10
# <style type="text/css">
# #T_4e1a2_row0_col0, #T_4e1a2_row0_col2, #T_4e1a2_row1_col1, #T_4e1a2_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_4e1a2_row0_col1, #T_4e1a2_row1_col0, #T_4e1a2_row1_col2, #T_4e1a2_row3_col3, #T_4e1a2_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_4e1a2_row0_col3, #T_4e1a2_row2_col1, #T_4e1a2_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_4e1a2_row1_col3, #T_4e1a2_row4_col0, #T_4e1a2_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_4e1a2_row2_col0 {
#   background-color: #35868d;
#   color: #f1f1f1;
# }
# #T_4e1a2_row2_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# #T_4e1a2_row3_col0 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_4e1a2_row3_col1, #T_4e1a2_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e1a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e1a2_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4e1a2_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4e1a2_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4e1a2_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e1a2_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_4e1a2_row0_col0" class="data row0 col0" >0.678</td>
#       <td id="T_4e1a2_row0_col1" class="data row0 col1" >0.855</td>
#       <td id="T_4e1a2_row0_col2" class="data row0 col2" >0.756</td>
#       <td id="T_4e1a2_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e1a2_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_4e1a2_row1_col0" class="data row1 col0" >0.881</td>
#       <td id="T_4e1a2_row1_col1" class="data row1 col1" >0.727</td>
#       <td id="T_4e1a2_row1_col2" class="data row1 col2" >0.796</td>
#       <td id="T_4e1a2_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e1a2_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4e1a2_row2_col0" class="data row2 col0" >0.778</td>
#       <td id="T_4e1a2_row2_col1" class="data row2 col1" >0.778</td>
#       <td id="T_4e1a2_row2_col2" class="data row2 col2" >0.778</td>
#       <td id="T_4e1a2_row2_col3" class="data row2 col3" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_4e1a2_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4e1a2_row3_col0" class="data row3 col0" >0.780</td>
#       <td id="T_4e1a2_row3_col1" class="data row3 col1" >0.791</td>
#       <td id="T_4e1a2_row3_col2" class="data row3 col2" >0.776</td>
#       <td id="T_4e1a2_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e1a2_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4e1a2_row4_col0" class="data row4 col0" >0.800</td>
#       <td id="T_4e1a2_row4_col1" class="data row4 col1" >0.778</td>
#       <td id="T_4e1a2_row4_col2" class="data row4 col2" >0.780</td>
#       <td id="T_4e1a2_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 20
# <style type="text/css">
# #T_468fa_row0_col0, #T_468fa_row0_col2, #T_468fa_row1_col1, #T_468fa_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_468fa_row0_col1, #T_468fa_row1_col0, #T_468fa_row1_col2, #T_468fa_row3_col3, #T_468fa_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_468fa_row0_col3, #T_468fa_row2_col1, #T_468fa_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_468fa_row1_col3, #T_468fa_row4_col0, #T_468fa_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_468fa_row2_col0 {
#   background-color: #31828d;
#   color: #f1f1f1;
# }
# #T_468fa_row2_col2 {
#   background-color: #2a7d8c;
#   color: #f1f1f1;
# }
# #T_468fa_row3_col0, #T_468fa_row3_col1, #T_468fa_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_468fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_468fa_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_468fa_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_468fa_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_468fa_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_468fa_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_468fa_row0_col0" class="data row0 col0" >0.695</td>
#       <td id="T_468fa_row0_col1" class="data row0 col1" >0.831</td>
#       <td id="T_468fa_row0_col2" class="data row0 col2" >0.757</td>
#       <td id="T_468fa_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_468fa_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_468fa_row1_col0" class="data row1 col0" >0.869</td>
#       <td id="T_468fa_row1_col1" class="data row1 col1" >0.755</td>
#       <td id="T_468fa_row1_col2" class="data row1 col2" >0.808</td>
#       <td id="T_468fa_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_468fa_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_468fa_row2_col0" class="data row2 col0" >0.785</td>
#       <td id="T_468fa_row2_col1" class="data row2 col1" >0.785</td>
#       <td id="T_468fa_row2_col2" class="data row2 col2" >0.785</td>
#       <td id="T_468fa_row2_col3" class="data row2 col3" >0.785</td>
#     </tr>
#     <tr>
#       <th id="T_468fa_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_468fa_row3_col0" class="data row3 col0" >0.782</td>
#       <td id="T_468fa_row3_col1" class="data row3 col1" >0.793</td>
#       <td id="T_468fa_row3_col2" class="data row3 col2" >0.783</td>
#       <td id="T_468fa_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_468fa_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_468fa_row4_col0" class="data row4 col0" >0.799</td>
#       <td id="T_468fa_row4_col1" class="data row4 col1" >0.785</td>
#       <td id="T_468fa_row4_col2" class="data row4 col2" >0.787</td>
#       <td id="T_468fa_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 30
# <style type="text/css">
# #T_c996c_row0_col0, #T_c996c_row0_col2, #T_c996c_row1_col1, #T_c996c_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_c996c_row0_col1, #T_c996c_row1_col0, #T_c996c_row1_col2, #T_c996c_row3_col3, #T_c996c_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_c996c_row0_col3, #T_c996c_row2_col1, #T_c996c_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_c996c_row1_col3, #T_c996c_row4_col0, #T_c996c_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_c996c_row2_col0 {
#   background-color: #33848d;
#   color: #f1f1f1;
# }
# #T_c996c_row2_col2 {
#   background-color: #2b7d8c;
#   color: #f1f1f1;
# }
# #T_c996c_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_c996c_row3_col1, #T_c996c_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c996c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c996c_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c996c_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c996c_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c996c_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c996c_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_c996c_row0_col0" class="data row0 col0" >0.691</td>
#       <td id="T_c996c_row0_col1" class="data row0 col1" >0.847</td>
#       <td id="T_c996c_row0_col2" class="data row0 col2" >0.761</td>
#       <td id="T_c996c_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_c996c_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_c996c_row1_col0" class="data row1 col0" >0.879</td>
#       <td id="T_c996c_row1_col1" class="data row1 col1" >0.745</td>
#       <td id="T_c996c_row1_col2" class="data row1 col2" >0.806</td>
#       <td id="T_c996c_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_c996c_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_c996c_row2_col0" class="data row2 col0" >0.786</td>
#       <td id="T_c996c_row2_col1" class="data row2 col1" >0.786</td>
#       <td id="T_c996c_row2_col2" class="data row2 col2" >0.786</td>
#       <td id="T_c996c_row2_col3" class="data row2 col3" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_c996c_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_c996c_row3_col0" class="data row3 col0" >0.785</td>
#       <td id="T_c996c_row3_col1" class="data row3 col1" >0.796</td>
#       <td id="T_c996c_row3_col2" class="data row3 col2" >0.784</td>
#       <td id="T_c996c_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_c996c_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_c996c_row4_col0" class="data row4 col0" >0.803</td>
#       <td id="T_c996c_row4_col1" class="data row4 col1" >0.786</td>
#       <td id="T_c996c_row4_col2" class="data row4 col2" >0.788</td>
#       <td id="T_c996c_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 40
# <style type="text/css">
# #T_adacb_row0_col0, #T_adacb_row0_col2, #T_adacb_row1_col1, #T_adacb_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_adacb_row0_col1, #T_adacb_row1_col0, #T_adacb_row1_col2, #T_adacb_row3_col3, #T_adacb_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_adacb_row0_col3, #T_adacb_row2_col1, #T_adacb_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_adacb_row1_col3, #T_adacb_row4_col0, #T_adacb_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_adacb_row2_col0 {
#   background-color: #33848d;
#   color: #f1f1f1;
# }
# #T_adacb_row2_col2 {
#   background-color: #2b7d8c;
#   color: #f1f1f1;
# }
# #T_adacb_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_adacb_row3_col1, #T_adacb_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_adacb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adacb_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_adacb_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_adacb_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_adacb_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adacb_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_adacb_row0_col0" class="data row0 col0" >0.687</td>
#       <td id="T_adacb_row0_col1" class="data row0 col1" >0.844</td>
#       <td id="T_adacb_row0_col2" class="data row0 col2" >0.757</td>
#       <td id="T_adacb_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_adacb_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_adacb_row1_col0" class="data row1 col0" >0.876</td>
#       <td id="T_adacb_row1_col1" class="data row1 col1" >0.741</td>
#       <td id="T_adacb_row1_col2" class="data row1 col2" >0.803</td>
#       <td id="T_adacb_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_adacb_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_adacb_row2_col0" class="data row2 col0" >0.782</td>
#       <td id="T_adacb_row2_col1" class="data row2 col1" >0.782</td>
#       <td id="T_adacb_row2_col2" class="data row2 col2" >0.782</td>
#       <td id="T_adacb_row2_col3" class="data row2 col3" >0.782</td>
#     </tr>
#     <tr>
#       <th id="T_adacb_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_adacb_row3_col0" class="data row3 col0" >0.781</td>
#       <td id="T_adacb_row3_col1" class="data row3 col1" >0.792</td>
#       <td id="T_adacb_row3_col2" class="data row3 col2" >0.780</td>
#       <td id="T_adacb_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_adacb_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_adacb_row4_col0" class="data row4 col0" >0.800</td>
#       <td id="T_adacb_row4_col1" class="data row4 col1" >0.782</td>
#       <td id="T_adacb_row4_col2" class="data row4 col2" >0.784</td>
#       <td id="T_adacb_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 50
# <style type="text/css">
# #T_83b3a_row0_col0, #T_83b3a_row0_col2, #T_83b3a_row1_col1, #T_83b3a_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_83b3a_row0_col1, #T_83b3a_row1_col0, #T_83b3a_row1_col2, #T_83b3a_row3_col3, #T_83b3a_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_83b3a_row0_col3, #T_83b3a_row2_col1, #T_83b3a_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_83b3a_row1_col3, #T_83b3a_row4_col0, #T_83b3a_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_83b3a_row2_col0, #T_83b3a_row3_col0, #T_83b3a_row3_col1, #T_83b3a_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_83b3a_row2_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83b3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83b3a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_83b3a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_83b3a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_83b3a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83b3a_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_83b3a_row0_col0" class="data row0 col0" >0.685</td>
#       <td id="T_83b3a_row0_col1" class="data row0 col1" >0.847</td>
#       <td id="T_83b3a_row0_col2" class="data row0 col2" >0.757</td>
#       <td id="T_83b3a_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_83b3a_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_83b3a_row1_col0" class="data row1 col0" >0.877</td>
#       <td id="T_83b3a_row1_col1" class="data row1 col1" >0.737</td>
#       <td id="T_83b3a_row1_col2" class="data row1 col2" >0.801</td>
#       <td id="T_83b3a_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_83b3a_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_83b3a_row2_col0" class="data row2 col0" >0.782</td>
#       <td id="T_83b3a_row2_col1" class="data row2 col1" >0.782</td>
#       <td id="T_83b3a_row2_col2" class="data row2 col2" >0.782</td>
#       <td id="T_83b3a_row2_col3" class="data row2 col3" >0.782</td>
#     </tr>
#     <tr>
#       <th id="T_83b3a_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_83b3a_row3_col0" class="data row3 col0" >0.781</td>
#       <td id="T_83b3a_row3_col1" class="data row3 col1" >0.792</td>
#       <td id="T_83b3a_row3_col2" class="data row3 col2" >0.779</td>
#       <td id="T_83b3a_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_83b3a_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_83b3a_row4_col0" class="data row4 col0" >0.800</td>
#       <td id="T_83b3a_row4_col1" class="data row4 col1" >0.782</td>
#       <td id="T_83b3a_row4_col2" class="data row4 col2" >0.784</td>
#       <td id="T_83b3a_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 60
# <style type="text/css">
# #T_429be_row0_col0, #T_429be_row0_col2, #T_429be_row1_col1, #T_429be_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_429be_row0_col1, #T_429be_row1_col0, #T_429be_row1_col2, #T_429be_row3_col3, #T_429be_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_429be_row0_col3, #T_429be_row2_col1, #T_429be_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_429be_row1_col3, #T_429be_row4_col0, #T_429be_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_429be_row2_col0, #T_429be_row3_col1, #T_429be_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_429be_row2_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# #T_429be_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_429be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_429be_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_429be_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_429be_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_429be_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_429be_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_429be_row0_col0" class="data row0 col0" >0.686</td>
#       <td id="T_429be_row0_col1" class="data row0 col1" >0.851</td>
#       <td id="T_429be_row0_col2" class="data row0 col2" >0.760</td>
#       <td id="T_429be_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_429be_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_429be_row1_col0" class="data row1 col0" >0.880</td>
#       <td id="T_429be_row1_col1" class="data row1 col1" >0.737</td>
#       <td id="T_429be_row1_col2" class="data row1 col2" >0.803</td>
#       <td id="T_429be_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_429be_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_429be_row2_col0" class="data row2 col0" >0.783</td>
#       <td id="T_429be_row2_col1" class="data row2 col1" >0.783</td>
#       <td id="T_429be_row2_col2" class="data row2 col2" >0.783</td>
#       <td id="T_429be_row2_col3" class="data row2 col3" >0.783</td>
#     </tr>
#     <tr>
#       <th id="T_429be_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_429be_row3_col0" class="data row3 col0" >0.783</td>
#       <td id="T_429be_row3_col1" class="data row3 col1" >0.794</td>
#       <td id="T_429be_row3_col2" class="data row3 col2" >0.781</td>
#       <td id="T_429be_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_429be_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_429be_row4_col0" class="data row4 col0" >0.802</td>
#       <td id="T_429be_row4_col1" class="data row4 col1" >0.783</td>
#       <td id="T_429be_row4_col2" class="data row4 col2" >0.785</td>
#       <td id="T_429be_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 70
# <style type="text/css">
# #T_d1b04_row0_col0, #T_d1b04_row0_col2, #T_d1b04_row1_col1, #T_d1b04_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_d1b04_row0_col1, #T_d1b04_row1_col0, #T_d1b04_row1_col2, #T_d1b04_row3_col3, #T_d1b04_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_d1b04_row0_col3, #T_d1b04_row2_col1, #T_d1b04_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_d1b04_row1_col3, #T_d1b04_row4_col0, #T_d1b04_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_d1b04_row2_col0 {
#   background-color: #35868d;
#   color: #f1f1f1;
# }
# #T_d1b04_row2_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# #T_d1b04_row3_col0, #T_d1b04_row3_col1 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_d1b04_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d1b04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1b04_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_d1b04_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_d1b04_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_d1b04_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1b04_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_d1b04_row0_col0" class="data row0 col0" >0.677</td>
#       <td id="T_d1b04_row0_col1" class="data row0 col1" >0.853</td>
#       <td id="T_d1b04_row0_col2" class="data row0 col2" >0.755</td>
#       <td id="T_d1b04_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_d1b04_row1_col0" class="data row1 col0" >0.880</td>
#       <td id="T_d1b04_row1_col1" class="data row1 col1" >0.726</td>
#       <td id="T_d1b04_row1_col2" class="data row1 col2" >0.795</td>
#       <td id="T_d1b04_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_d1b04_row2_col0" class="data row2 col0" >0.777</td>
#       <td id="T_d1b04_row2_col1" class="data row2 col1" >0.777</td>
#       <td id="T_d1b04_row2_col2" class="data row2 col2" >0.777</td>
#       <td id="T_d1b04_row2_col3" class="data row2 col3" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_d1b04_row3_col0" class="data row3 col0" >0.778</td>
#       <td id="T_d1b04_row3_col1" class="data row3 col1" >0.789</td>
#       <td id="T_d1b04_row3_col2" class="data row3 col2" >0.775</td>
#       <td id="T_d1b04_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_d1b04_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_d1b04_row4_col0" class="data row4 col0" >0.798</td>
#       <td id="T_d1b04_row4_col1" class="data row4 col1" >0.777</td>
#       <td id="T_d1b04_row4_col2" class="data row4 col2" >0.779</td>
#       <td id="T_d1b04_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para numero de vizinhos igual a 80
# <style type="text/css">
# #T_3cfa1_row0_col0, #T_3cfa1_row0_col2, #T_3cfa1_row1_col1, #T_3cfa1_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_3cfa1_row0_col1, #T_3cfa1_row1_col0, #T_3cfa1_row1_col2, #T_3cfa1_row3_col3, #T_3cfa1_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_3cfa1_row0_col3, #T_3cfa1_row2_col1, #T_3cfa1_row4_col1 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# #T_3cfa1_row1_col3, #T_3cfa1_row4_col0, #T_3cfa1_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_3cfa1_row2_col0 {
#   background-color: #35878d;
#   color: #f1f1f1;
# }
# #T_3cfa1_row2_col2 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# #T_3cfa1_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_3cfa1_row3_col1, #T_3cfa1_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3cfa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cfa1_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_3cfa1_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_3cfa1_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_3cfa1_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cfa1_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_3cfa1_row0_col0" class="data row0 col0" >0.676</td>
#       <td id="T_3cfa1_row0_col1" class="data row0 col1" >0.854</td>
#       <td id="T_3cfa1_row0_col2" class="data row0 col2" >0.754</td>
#       <td id="T_3cfa1_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_3cfa1_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_3cfa1_row1_col0" class="data row1 col0" >0.880</td>
#       <td id="T_3cfa1_row1_col1" class="data row1 col1" >0.724</td>
#       <td id="T_3cfa1_row1_col2" class="data row1 col2" >0.794</td>
#       <td id="T_3cfa1_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_3cfa1_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_3cfa1_row2_col0" class="data row2 col0" >0.776</td>
#       <td id="T_3cfa1_row2_col1" class="data row2 col1" >0.776</td>
#       <td id="T_3cfa1_row2_col2" class="data row2 col2" >0.776</td>
#       <td id="T_3cfa1_row2_col3" class="data row2 col3" >0.776</td>
#     </tr>
#     <tr>
#       <th id="T_3cfa1_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_3cfa1_row3_col0" class="data row3 col0" >0.778</td>
#       <td id="T_3cfa1_row3_col1" class="data row3 col1" >0.789</td>
#       <td id="T_3cfa1_row3_col2" class="data row3 col2" >0.774</td>
#       <td id="T_3cfa1_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_3cfa1_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_3cfa1_row4_col0" class="data row4 col0" >0.798</td>
#       <td id="T_3cfa1_row4_col1" class="data row4 col1" >0.776</td>
#       <td id="T_3cfa1_row4_col2" class="data row4 col2" >0.778</td>
#       <td id="T_3cfa1_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matriz de Confusão

# %%
for i in range(len(dfResumosClassificacao)):
    print("Matriz de confusão para numero de vizinhos igual a", numerosNeighbors[i])
    
    # Obtem a matriz de confusão
    confusionMatrix = confusion_matrix(y_test, y_preds[i])

    # Desenha a matriz de confusão
    plt.figure(figsize=(3, 3))
    sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
    plt.title('Matriz de Confusão')
    plt.xlabel('Rótulo Falso Verdadeiro')
    plt.ylabel('Rótulo Verdadeiro')
    plt.grid(False)
    plt.show()

    totalRotulos = X_test.shape[0]
    corretamenteRotulados = (y_test == y_preds[i]).sum()
    incorretamenteRotulados = (y_test != y_preds[i]).sum()

    print("Número de pontos corretamente rotulados de um total de", totalRotulos, "pontos:", corretamenteRotulados, "(", round((corretamenteRotulados / totalRotulos) * 100), "%)")
    print("Número de pontos incorretamente rotulados de um total de", totalRotulos, "pontos:", incorretamenteRotulados, "(", round((incorretamenteRotulados / totalRotulos) * 100), "%) \n")
# Out:
# Matriz de confusão para numero de vizinhos igual a 10
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2024 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 577 ( 22 %)
#
# Matriz de confusão para numero de vizinhos igual a 20
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2043 ( 79 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 558 ( 21 %)
#
# Matriz de confusão para numero de vizinhos igual a 30
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2044 ( 79 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 557 ( 21 %)
#
# Matriz de confusão para numero de vizinhos igual a 40
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2035 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 566 ( 22 %)
#
# Matriz de confusão para numero de vizinhos igual a 50
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2033 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 568 ( 22 %)
#
# Matriz de confusão para numero de vizinhos igual a 60
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2037 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 564 ( 22 %)
#
# Matriz de confusão para numero de vizinhos igual a 70
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2021 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 580 ( 22 %)
#
# Matriz de confusão para numero de vizinhos igual a 80
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2019 ( 78 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 582 ( 22 %)

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold¶

# %%
dfResultadosAcuracia = pd.DataFrame({
'Acurácia': acuracias
}, index = numerosNeighbors)

mediasValidacoesCruzadas = [np.mean(k5Values) for k5Values in validacoesCruzadas]
dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada (média)': mediasValidacoesCruzadas
}, index = numerosNeighbors)


dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# <style type="text/css">
# #T_e2556_row0_col0 {
#   background-color: #6db290;
#   color: #f1f1f1;
# }
# #T_e2556_row1_col0 {
#   background-color: #2b3875;
#   color: #f1f1f1;
# }
# #T_e2556_row2_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_e2556_row3_col0 {
#   background-color: #1f708b;
#   color: #f1f1f1;
# }
# #T_e2556_row4_col0 {
#   background-color: #2a7c8c;
#   color: #f1f1f1;
# }
# #T_e2556_row5_col0 {
#   background-color: #1d6388;
#   color: #f1f1f1;
# }
# #T_e2556_row6_col0 {
#   background-color: #8fc291;
#   color: #000000;
# }
# #T_e2556_row7_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# </style>
# <table id="T_e2556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2556_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2556_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_e2556_row0_col0" class="data row0 col0" >0.778</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_e2556_row1_col0" class="data row1 col0" >0.785</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_e2556_row2_col0" class="data row2 col0" >0.786</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_e2556_row3_col0" class="data row3 col0" >0.782</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_e2556_row4_col0" class="data row4 col0" >0.782</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_e2556_row5_col0" class="data row5 col0" >0.783</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_e2556_row6_col0" class="data row6 col0" >0.777</td>
#     </tr>
#     <tr>
#       <th id="T_e2556_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_e2556_row7_col0" class="data row7 col0" >0.776</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_deddb_row0_col0 {
#   background-color: #54a290;
#   color: #f1f1f1;
# }
# #T_deddb_row1_col0 {
#   background-color: #1e5c86;
#   color: #f1f1f1;
# }
# #T_deddb_row2_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_deddb_row3_col0 {
#   background-color: #1d6288;
#   color: #f1f1f1;
# }
# #T_deddb_row4_col0 {
#   background-color: #21738b;
#   color: #f1f1f1;
# }
# #T_deddb_row5_col0 {
#   background-color: #5ba790;
#   color: #f1f1f1;
# }
# #T_deddb_row6_col0 {
#   background-color: #88bf91;
#   color: #000000;
# }
# #T_deddb_row7_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# </style>
# <table id="T_deddb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_deddb_level0_col0" class="col_heading level0 col0" >Validação Cruzada (média)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_deddb_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_deddb_row0_col0" class="data row0 col0" >0.766</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_deddb_row1_col0" class="data row1 col0" >0.771</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_deddb_row2_col0" class="data row2 col0" >0.774</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_deddb_row3_col0" class="data row3 col0" >0.771</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_deddb_row4_col0" class="data row4 col0" >0.770</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_deddb_row5_col0" class="data row5 col0" >0.766</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_deddb_row6_col0" class="data row6 col0" >0.764</td>
#     </tr>
#     <tr>
#       <th id="T_deddb_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_deddb_row7_col0" class="data row7 col0" >0.763</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparação da Acurácia e Validação Cruzada K-fold

# %%
plt.plot(numerosNeighbors, acuracias, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Acurácia')
plt.title('Variação da Acurácia em relação ao Número de Árvores')
plt.grid(False)
plt.show()

plt.plot(numerosNeighbors, validacoesCruzadas, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Validação Cruzada')
plt.title('Variação da Validação Cruzada em relação ao Número de Árvores')
plt.grid(False)
plt.show()

# %% [markdown]
# ## Inferência Sobre os Resultados

# %% [markdown]
# # Random Forest (RF)

# %%
numerosArvores = [10,20,30,40,50,60,70,80]
y_fits = []
y_preds = []
dfResumosClassificacao = []
acuracias = []
validacoesCruzadas = []

for numeroArvores in numerosArvores:

    clf = RandomForestClassifier(n_estimators=numeroArvores)

    y_fit = clf.fit(X_train, y_train)
    y_fits.append(y_fit)
    
    y_pred = y_fit.predict(X_test)
    y_preds.append(y_pred)

    resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
    dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda
    dfResumosClassificacao.append(dfResumoClassificacao)
    
    acuracia = accuracy_score(y_test, y_pred)
    acuracias.append(acuracia)
    
    validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)
    validacoesCruzadas.append(validacaoCruzada)
    
melhoresAcuracias[5] = acuracia

# %% [markdown]
# ## Gráficos Resultados

# %% [markdown]
# Os testes realizados utilizando o método Random Forest nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
for i in range(len(dfResumosClassificacao)):
    dfResumoClassificacaoEstilizada = dfResumosClassificacao[i].style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

    print("Resumo da classificação para número de arvores igual a", numerosArvores[i])
    display(dfResumoClassificacaoEstilizada)
# Out:
# Resumo da classificação para número de arvores igual a 10
# <style type="text/css">
# #T_ba6d9_row0_col0, #T_ba6d9_row0_col1, #T_ba6d9_row0_col2, #T_ba6d9_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_ba6d9_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_ba6d9_row1_col0, #T_ba6d9_row1_col1, #T_ba6d9_row1_col2, #T_ba6d9_row3_col3, #T_ba6d9_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_ba6d9_row1_col3, #T_ba6d9_row2_col0, #T_ba6d9_row2_col1, #T_ba6d9_row2_col2, #T_ba6d9_row4_col0, #T_ba6d9_row4_col1, #T_ba6d9_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_ba6d9_row3_col0, #T_ba6d9_row3_col1, #T_ba6d9_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ba6d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba6d9_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_ba6d9_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_ba6d9_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_ba6d9_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6d9_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_ba6d9_row0_col0" class="data row0 col0" >0.957</td>
#       <td id="T_ba6d9_row0_col1" class="data row0 col1" >0.960</td>
#       <td id="T_ba6d9_row0_col2" class="data row0 col2" >0.959</td>
#       <td id="T_ba6d9_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d9_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_ba6d9_row1_col0" class="data row1 col0" >0.973</td>
#       <td id="T_ba6d9_row1_col1" class="data row1 col1" >0.971</td>
#       <td id="T_ba6d9_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_ba6d9_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d9_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_ba6d9_row2_col0" class="data row2 col0" >0.967</td>
#       <td id="T_ba6d9_row2_col1" class="data row2 col1" >0.967</td>
#       <td id="T_ba6d9_row2_col2" class="data row2 col2" >0.967</td>
#       <td id="T_ba6d9_row2_col3" class="data row2 col3" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d9_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_ba6d9_row3_col0" class="data row3 col0" >0.965</td>
#       <td id="T_ba6d9_row3_col1" class="data row3 col1" >0.965</td>
#       <td id="T_ba6d9_row3_col2" class="data row3 col2" >0.965</td>
#       <td id="T_ba6d9_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d9_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_ba6d9_row4_col0" class="data row4 col0" >0.967</td>
#       <td id="T_ba6d9_row4_col1" class="data row4 col1" >0.967</td>
#       <td id="T_ba6d9_row4_col2" class="data row4 col2" >0.967</td>
#       <td id="T_ba6d9_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 20
# <style type="text/css">
# #T_2fe86_row0_col0, #T_2fe86_row0_col1, #T_2fe86_row0_col2, #T_2fe86_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_2fe86_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_2fe86_row1_col0, #T_2fe86_row1_col1, #T_2fe86_row1_col2, #T_2fe86_row3_col3, #T_2fe86_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_2fe86_row1_col3, #T_2fe86_row2_col1, #T_2fe86_row4_col0, #T_2fe86_row4_col1, #T_2fe86_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_2fe86_row2_col0, #T_2fe86_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_2fe86_row3_col0, #T_2fe86_row3_col1 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_2fe86_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2fe86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fe86_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_2fe86_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_2fe86_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_2fe86_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fe86_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_2fe86_row0_col0" class="data row0 col0" >0.960</td>
#       <td id="T_2fe86_row0_col1" class="data row0 col1" >0.956</td>
#       <td id="T_2fe86_row0_col2" class="data row0 col2" >0.958</td>
#       <td id="T_2fe86_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_2fe86_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_2fe86_row1_col0" class="data row1 col0" >0.970</td>
#       <td id="T_2fe86_row1_col1" class="data row1 col1" >0.973</td>
#       <td id="T_2fe86_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_2fe86_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_2fe86_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_2fe86_row2_col0" class="data row2 col0" >0.966</td>
#       <td id="T_2fe86_row2_col1" class="data row2 col1" >0.966</td>
#       <td id="T_2fe86_row2_col2" class="data row2 col2" >0.966</td>
#       <td id="T_2fe86_row2_col3" class="data row2 col3" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_2fe86_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_2fe86_row3_col0" class="data row3 col0" >0.965</td>
#       <td id="T_2fe86_row3_col1" class="data row3 col1" >0.965</td>
#       <td id="T_2fe86_row3_col2" class="data row3 col2" >0.965</td>
#       <td id="T_2fe86_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_2fe86_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_2fe86_row4_col0" class="data row4 col0" >0.966</td>
#       <td id="T_2fe86_row4_col1" class="data row4 col1" >0.966</td>
#       <td id="T_2fe86_row4_col2" class="data row4 col2" >0.966</td>
#       <td id="T_2fe86_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 30
# <style type="text/css">
# #T_902b3_row0_col0, #T_902b3_row1_col1, #T_902b3_row1_col2, #T_902b3_row3_col3, #T_902b3_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_902b3_row0_col1, #T_902b3_row0_col2, #T_902b3_row1_col0, #T_902b3_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_902b3_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_902b3_row1_col3, #T_902b3_row2_col1, #T_902b3_row4_col1, #T_902b3_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_902b3_row2_col0 {
#   background-color: #45958f;
#   color: #f1f1f1;
# }
# #T_902b3_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_902b3_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_902b3_row3_col1, #T_902b3_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_902b3_row4_col0 {
#   background-color: #43948f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_902b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_902b3_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_902b3_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_902b3_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_902b3_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_902b3_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_902b3_row0_col0" class="data row0 col0" >0.963</td>
#       <td id="T_902b3_row0_col1" class="data row0 col1" >0.944</td>
#       <td id="T_902b3_row0_col2" class="data row0 col2" >0.953</td>
#       <td id="T_902b3_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_902b3_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_902b3_row1_col0" class="data row1 col0" >0.963</td>
#       <td id="T_902b3_row1_col1" class="data row1 col1" >0.976</td>
#       <td id="T_902b3_row1_col2" class="data row1 col2" >0.969</td>
#       <td id="T_902b3_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_902b3_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_902b3_row2_col0" class="data row2 col0" >0.963</td>
#       <td id="T_902b3_row2_col1" class="data row2 col1" >0.963</td>
#       <td id="T_902b3_row2_col2" class="data row2 col2" >0.963</td>
#       <td id="T_902b3_row2_col3" class="data row2 col3" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_902b3_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_902b3_row3_col0" class="data row3 col0" >0.963</td>
#       <td id="T_902b3_row3_col1" class="data row3 col1" >0.960</td>
#       <td id="T_902b3_row3_col2" class="data row3 col2" >0.961</td>
#       <td id="T_902b3_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_902b3_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_902b3_row4_col0" class="data row4 col0" >0.963</td>
#       <td id="T_902b3_row4_col1" class="data row4 col1" >0.963</td>
#       <td id="T_902b3_row4_col2" class="data row4 col2" >0.963</td>
#       <td id="T_902b3_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 40
# <style type="text/css">
# #T_0845b_row0_col0, #T_0845b_row0_col1, #T_0845b_row0_col2, #T_0845b_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_0845b_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_0845b_row1_col0, #T_0845b_row1_col1, #T_0845b_row1_col2, #T_0845b_row3_col3, #T_0845b_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_0845b_row1_col3, #T_0845b_row2_col1, #T_0845b_row4_col0, #T_0845b_row4_col1, #T_0845b_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_0845b_row2_col0 {
#   background-color: #23758b;
#   color: #f1f1f1;
# }
# #T_0845b_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_0845b_row3_col0, #T_0845b_row3_col1, #T_0845b_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0845b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0845b_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0845b_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0845b_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0845b_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0845b_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_0845b_row0_col0" class="data row0 col0" >0.963</td>
#       <td id="T_0845b_row0_col1" class="data row0 col1" >0.948</td>
#       <td id="T_0845b_row0_col2" class="data row0 col2" >0.956</td>
#       <td id="T_0845b_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_0845b_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_0845b_row1_col0" class="data row1 col0" >0.966</td>
#       <td id="T_0845b_row1_col1" class="data row1 col1" >0.976</td>
#       <td id="T_0845b_row1_col2" class="data row1 col2" >0.971</td>
#       <td id="T_0845b_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_0845b_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_0845b_row2_col0" class="data row2 col0" >0.965</td>
#       <td id="T_0845b_row2_col1" class="data row2 col1" >0.965</td>
#       <td id="T_0845b_row2_col2" class="data row2 col2" >0.965</td>
#       <td id="T_0845b_row2_col3" class="data row2 col3" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_0845b_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_0845b_row3_col0" class="data row3 col0" >0.964</td>
#       <td id="T_0845b_row3_col1" class="data row3 col1" >0.962</td>
#       <td id="T_0845b_row3_col2" class="data row3 col2" >0.963</td>
#       <td id="T_0845b_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_0845b_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_0845b_row4_col0" class="data row4 col0" >0.965</td>
#       <td id="T_0845b_row4_col1" class="data row4 col1" >0.965</td>
#       <td id="T_0845b_row4_col2" class="data row4 col2" >0.965</td>
#       <td id="T_0845b_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 50
# <style type="text/css">
# #T_c6123_row0_col0, #T_c6123_row0_col1, #T_c6123_row0_col2, #T_c6123_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_c6123_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_c6123_row1_col0, #T_c6123_row1_col1, #T_c6123_row1_col2, #T_c6123_row3_col3, #T_c6123_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_c6123_row1_col3, #T_c6123_row2_col1, #T_c6123_row4_col0, #T_c6123_row4_col1, #T_c6123_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_c6123_row2_col0 {
#   background-color: #23758b;
#   color: #f1f1f1;
# }
# #T_c6123_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_c6123_row3_col0, #T_c6123_row3_col1, #T_c6123_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6123">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6123_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c6123_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c6123_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c6123_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6123_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_c6123_row0_col0" class="data row0 col0" >0.961</td>
#       <td id="T_c6123_row0_col1" class="data row0 col1" >0.950</td>
#       <td id="T_c6123_row0_col2" class="data row0 col2" >0.956</td>
#       <td id="T_c6123_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_c6123_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_c6123_row1_col0" class="data row1 col0" >0.967</td>
#       <td id="T_c6123_row1_col1" class="data row1 col1" >0.974</td>
#       <td id="T_c6123_row1_col2" class="data row1 col2" >0.971</td>
#       <td id="T_c6123_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_c6123_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_c6123_row2_col0" class="data row2 col0" >0.965</td>
#       <td id="T_c6123_row2_col1" class="data row2 col1" >0.965</td>
#       <td id="T_c6123_row2_col2" class="data row2 col2" >0.965</td>
#       <td id="T_c6123_row2_col3" class="data row2 col3" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_c6123_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_c6123_row3_col0" class="data row3 col0" >0.964</td>
#       <td id="T_c6123_row3_col1" class="data row3 col1" >0.962</td>
#       <td id="T_c6123_row3_col2" class="data row3 col2" >0.963</td>
#       <td id="T_c6123_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_c6123_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_c6123_row4_col0" class="data row4 col0" >0.965</td>
#       <td id="T_c6123_row4_col1" class="data row4 col1" >0.965</td>
#       <td id="T_c6123_row4_col2" class="data row4 col2" >0.965</td>
#       <td id="T_c6123_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 60
# <style type="text/css">
# #T_f3758_row0_col0, #T_f3758_row0_col1, #T_f3758_row0_col2, #T_f3758_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_f3758_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_f3758_row1_col0, #T_f3758_row1_col1, #T_f3758_row1_col2, #T_f3758_row3_col3, #T_f3758_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_f3758_row1_col3, #T_f3758_row2_col1, #T_f3758_row4_col0, #T_f3758_row4_col1, #T_f3758_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_f3758_row2_col0 {
#   background-color: #23758b;
#   color: #f1f1f1;
# }
# #T_f3758_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_f3758_row3_col0, #T_f3758_row3_col1, #T_f3758_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3758_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_f3758_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_f3758_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_f3758_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3758_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_f3758_row0_col0" class="data row0 col0" >0.964</td>
#       <td id="T_f3758_row0_col1" class="data row0 col1" >0.950</td>
#       <td id="T_f3758_row0_col2" class="data row0 col2" >0.957</td>
#       <td id="T_f3758_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_f3758_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_f3758_row1_col0" class="data row1 col0" >0.967</td>
#       <td id="T_f3758_row1_col1" class="data row1 col1" >0.976</td>
#       <td id="T_f3758_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_f3758_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_f3758_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_f3758_row2_col0" class="data row2 col0" >0.966</td>
#       <td id="T_f3758_row2_col1" class="data row2 col1" >0.966</td>
#       <td id="T_f3758_row2_col2" class="data row2 col2" >0.966</td>
#       <td id="T_f3758_row2_col3" class="data row2 col3" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_f3758_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_f3758_row3_col0" class="data row3 col0" >0.966</td>
#       <td id="T_f3758_row3_col1" class="data row3 col1" >0.963</td>
#       <td id="T_f3758_row3_col2" class="data row3 col2" >0.964</td>
#       <td id="T_f3758_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_f3758_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_f3758_row4_col0" class="data row4 col0" >0.966</td>
#       <td id="T_f3758_row4_col1" class="data row4 col1" >0.966</td>
#       <td id="T_f3758_row4_col2" class="data row4 col2" >0.966</td>
#       <td id="T_f3758_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 70
# <style type="text/css">
# #T_071fc_row0_col0, #T_071fc_row0_col1, #T_071fc_row0_col2, #T_071fc_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_071fc_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_071fc_row1_col0, #T_071fc_row1_col1, #T_071fc_row1_col2, #T_071fc_row3_col3, #T_071fc_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_071fc_row1_col3, #T_071fc_row2_col1, #T_071fc_row4_col0, #T_071fc_row4_col1, #T_071fc_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_071fc_row2_col0 {
#   background-color: #23758b;
#   color: #f1f1f1;
# }
# #T_071fc_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_071fc_row3_col0, #T_071fc_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_071fc_row3_col1 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_071fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_071fc_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_071fc_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_071fc_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_071fc_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_071fc_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_071fc_row0_col0" class="data row0 col0" >0.965</td>
#       <td id="T_071fc_row0_col1" class="data row0 col1" >0.951</td>
#       <td id="T_071fc_row0_col2" class="data row0 col2" >0.958</td>
#       <td id="T_071fc_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_071fc_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_071fc_row1_col0" class="data row1 col0" >0.967</td>
#       <td id="T_071fc_row1_col1" class="data row1 col1" >0.977</td>
#       <td id="T_071fc_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_071fc_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_071fc_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_071fc_row2_col0" class="data row2 col0" >0.967</td>
#       <td id="T_071fc_row2_col1" class="data row2 col1" >0.967</td>
#       <td id="T_071fc_row2_col2" class="data row2 col2" >0.967</td>
#       <td id="T_071fc_row2_col3" class="data row2 col3" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_071fc_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_071fc_row3_col0" class="data row3 col0" >0.966</td>
#       <td id="T_071fc_row3_col1" class="data row3 col1" >0.964</td>
#       <td id="T_071fc_row3_col2" class="data row3 col2" >0.965</td>
#       <td id="T_071fc_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_071fc_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_071fc_row4_col0" class="data row4 col0" >0.967</td>
#       <td id="T_071fc_row4_col1" class="data row4 col1" >0.967</td>
#       <td id="T_071fc_row4_col2" class="data row4 col2" >0.967</td>
#       <td id="T_071fc_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de arvores igual a 80
# <style type="text/css">
# #T_4c305_row0_col0, #T_4c305_row0_col1, #T_4c305_row0_col2, #T_4c305_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_4c305_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_4c305_row1_col0, #T_4c305_row1_col1, #T_4c305_row1_col2, #T_4c305_row3_col3, #T_4c305_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_4c305_row1_col3, #T_4c305_row2_col1, #T_4c305_row4_col0, #T_4c305_row4_col1, #T_4c305_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_4c305_row2_col0 {
#   background-color: #23758b;
#   color: #f1f1f1;
# }
# #T_4c305_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_4c305_row3_col0, #T_4c305_row3_col1, #T_4c305_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c305">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c305_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4c305_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4c305_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4c305_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c305_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_4c305_row0_col0" class="data row0 col0" >0.966</td>
#       <td id="T_4c305_row0_col1" class="data row0 col1" >0.950</td>
#       <td id="T_4c305_row0_col2" class="data row0 col2" >0.958</td>
#       <td id="T_4c305_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_4c305_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_4c305_row1_col0" class="data row1 col0" >0.967</td>
#       <td id="T_4c305_row1_col1" class="data row1 col1" >0.977</td>
#       <td id="T_4c305_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_4c305_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_4c305_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4c305_row2_col0" class="data row2 col0" >0.967</td>
#       <td id="T_4c305_row2_col1" class="data row2 col1" >0.967</td>
#       <td id="T_4c305_row2_col2" class="data row2 col2" >0.967</td>
#       <td id="T_4c305_row2_col3" class="data row2 col3" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_4c305_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4c305_row3_col0" class="data row3 col0" >0.966</td>
#       <td id="T_4c305_row3_col1" class="data row3 col1" >0.964</td>
#       <td id="T_4c305_row3_col2" class="data row3 col2" >0.965</td>
#       <td id="T_4c305_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_4c305_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4c305_row4_col0" class="data row4 col0" >0.967</td>
#       <td id="T_4c305_row4_col1" class="data row4 col1" >0.967</td>
#       <td id="T_4c305_row4_col2" class="data row4 col2" >0.967</td>
#       <td id="T_4c305_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matriz de Confusão

# %%
for i in range(len(dfResumosClassificacao)):
    print("Matriz de confusão para número de arvores igual a", numerosArvores[i])
    
    # Obtem a matriz de confusão
    confusionMatrix = confusion_matrix(y_test, y_preds[i])

    # Desenha a matriz de confusão
    plt.figure(figsize=(3, 3))
    sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
    plt.title('Matriz de Confusão')
    plt.xlabel('Rótulo Falso Verdadeiro')
    plt.ylabel('Rótulo Verdadeiro')
    plt.grid(False)
    plt.show()

    totalRotulos = X_test.shape[0]
    corretamenteRotulados = (y_test == y_preds[i]).sum()
    incorretamenteRotulados = (y_test != y_preds[i]).sum()

    print("Número de pontos corretamente rotulados de um total de", totalRotulos, "pontos:", corretamenteRotulados, "(", round((corretamenteRotulados / totalRotulos) * 100), "%)")
    print("Número de pontos incorretamente rotulados de um total de", totalRotulos, "pontos:", incorretamenteRotulados, "(", round((incorretamenteRotulados / totalRotulos) * 100), "%) \n")
# Out:
# Matriz de confusão para número de arvores igual a 10
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2514 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 87 ( 3 %)
#
# Matriz de confusão para número de arvores igual a 20
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2513 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 88 ( 3 %)
#
# Matriz de confusão para número de arvores igual a 30
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2504 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 97 ( 4 %)
#
# Matriz de confusão para número de arvores igual a 40
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2509 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 92 ( 4 %)
#
# Matriz de confusão para número de arvores igual a 50
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2509 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 92 ( 4 %)
#
# Matriz de confusão para número de arvores igual a 60
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2512 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 89 ( 3 %)
#
# Matriz de confusão para número de arvores igual a 70
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2514 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 87 ( 3 %)
#
# Matriz de confusão para número de arvores igual a 80
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2514 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 87 ( 3 %)

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold¶

# %%
dfResultadosAcuracia = pd.DataFrame({
'Acurácia': acuracias
}, index = numerosArvores)

mediasValidacoesCruzadas = [np.mean(k5Values) for k5Values in validacoesCruzadas]
dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada (média)': mediasValidacoesCruzadas
}, index = numerosArvores)


dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# <style type="text/css">
# #T_396a0_row0_col0, #T_396a0_row6_col0, #T_396a0_row7_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_396a0_row1_col0 {
#   background-color: #28437b;
#   color: #f1f1f1;
# }
# #T_396a0_row2_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_396a0_row3_col0, #T_396a0_row4_col0 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_396a0_row5_col0 {
#   background-color: #215584;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_396a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_396a0_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_396a0_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_396a0_row0_col0" class="data row0 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_396a0_row1_col0" class="data row1 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_396a0_row2_col0" class="data row2 col0" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_396a0_row3_col0" class="data row3 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_396a0_row4_col0" class="data row4 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_396a0_row5_col0" class="data row5 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_396a0_row6_col0" class="data row6 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_396a0_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_396a0_row7_col0" class="data row7 col0" >0.967</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c3e05_row0_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_c3e05_row1_col0, #T_c3e05_row6_col0 {
#   background-color: #1e6f8a;
#   color: #f1f1f1;
# }
# #T_c3e05_row2_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_c3e05_row3_col0 {
#   background-color: #22748b;
#   color: #f1f1f1;
# }
# #T_c3e05_row4_col0 {
#   background-color: #1c6488;
#   color: #f1f1f1;
# }
# #T_c3e05_row5_col0 {
#   background-color: #215483;
#   color: #f1f1f1;
# }
# #T_c3e05_row7_col0 {
#   background-color: #2c7e8c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c3e05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3e05_level0_col0" class="col_heading level0 col0" >Validação Cruzada (média)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3e05_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_c3e05_row0_col0" class="data row0 col0" >0.957</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_c3e05_row1_col0" class="data row1 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_c3e05_row2_col0" class="data row2 col0" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_c3e05_row3_col0" class="data row3 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_c3e05_row4_col0" class="data row4 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_c3e05_row5_col0" class="data row5 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_c3e05_row6_col0" class="data row6 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_c3e05_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_c3e05_row7_col0" class="data row7 col0" >0.964</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparação da Acurácia e Validação Cruzada K-fold¶

# %%
plt.plot(numerosArvores, acuracias, marker='o')
plt.xlabel('Número de Árvores')
plt.ylabel('Acurácia')
plt.title('Variação da Acurácia em relação ao Número de Árvores')
plt.grid(False)
plt.show()

plt.plot(numerosArvores, validacoesCruzadas, marker='o')
plt.xlabel('Número de Árvores')
plt.ylabel('Validação Cruzada')
plt.title('Variação da Validação Cruzada em relação ao Número de Árvores')
plt.grid(False)
plt.show()

# %% [markdown]
# ### Inferência Sobre os Resultados

# %% [markdown]
# # Gradient Tree Boosting (GTB)

# %%
numerosIteracoes = [10,20,30,40,50,60,70,80]
y_fits = []
y_preds = []
dfResumosClassificacao = []
acuracias = []
validacoesCruzadas = []

for numeroIteracoes in numerosIteracoes:

    clf = GradientBoostingClassifier(n_estimators=numeroIteracoes)

    y_fit = clf.fit(X_train, y_train)
    y_fits.append(y_fit)
    
    y_pred = y_fit.predict(X_test)
    y_preds.append(y_pred)

    resumoClassificacao = classification_report(y_test, y_pred, output_dict=True)
    dfResumoClassificacao = pd.DataFrame(resumoClassificacao).transpose() # Armazena em um df do panda
    dfResumosClassificacao.append(dfResumoClassificacao)
    
    acuracia = accuracy_score(y_test, y_pred)
    acuracias.append(acuracia)
    
    validacaoCruzada = cross_val_score(clf, X_train, y_train, cv=5)
    validacoesCruzadas.append(validacaoCruzada)
    
melhoresAcuracias[6] = acuracia

# %% [markdown]
# ## Gráficos Resultados

# %% [markdown]
# Os testes realizados utilizando o método Gradient Tree Boosting nos forneceram uma valiosa oportunidade de avaliar o desempenho desse algoritmo de classificação. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Classificação

# %%
for i in range(len(dfResumosClassificacao)):
    dfResumoClassificacaoEstilizada = dfResumosClassificacao[i].style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

    print("Resumo da classificação para número de iterações máximas igual a", numerosIteracoes[i])
    display(dfResumoClassificacaoEstilizada)
# Out:
# Resumo da classificação para número de iterações máximas igual a 10
# <style type="text/css">
# #T_a76e3_row0_col0, #T_a76e3_row0_col1, #T_a76e3_row0_col2, #T_a76e3_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_a76e3_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_a76e3_row1_col0, #T_a76e3_row1_col1, #T_a76e3_row1_col2, #T_a76e3_row3_col3, #T_a76e3_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_a76e3_row1_col3, #T_a76e3_row2_col1, #T_a76e3_row4_col0, #T_a76e3_row4_col1, #T_a76e3_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_a76e3_row2_col0, #T_a76e3_row2_col2 {
#   background-color: #24768b;
#   color: #f1f1f1;
# }
# #T_a76e3_row3_col0, #T_a76e3_row3_col1, #T_a76e3_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a76e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a76e3_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a76e3_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a76e3_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a76e3_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a76e3_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_a76e3_row0_col0" class="data row0 col0" >0.945</td>
#       <td id="T_a76e3_row0_col1" class="data row0 col1" >0.939</td>
#       <td id="T_a76e3_row0_col2" class="data row0 col2" >0.942</td>
#       <td id="T_a76e3_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_a76e3_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_a76e3_row1_col0" class="data row1 col0" >0.959</td>
#       <td id="T_a76e3_row1_col1" class="data row1 col1" >0.963</td>
#       <td id="T_a76e3_row1_col2" class="data row1 col2" >0.961</td>
#       <td id="T_a76e3_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_a76e3_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a76e3_row2_col0" class="data row2 col0" >0.953</td>
#       <td id="T_a76e3_row2_col1" class="data row2 col1" >0.953</td>
#       <td id="T_a76e3_row2_col2" class="data row2 col2" >0.953</td>
#       <td id="T_a76e3_row2_col3" class="data row2 col3" >0.953</td>
#     </tr>
#     <tr>
#       <th id="T_a76e3_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a76e3_row3_col0" class="data row3 col0" >0.952</td>
#       <td id="T_a76e3_row3_col1" class="data row3 col1" >0.951</td>
#       <td id="T_a76e3_row3_col2" class="data row3 col2" >0.952</td>
#       <td id="T_a76e3_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_a76e3_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a76e3_row4_col0" class="data row4 col0" >0.953</td>
#       <td id="T_a76e3_row4_col1" class="data row4 col1" >0.953</td>
#       <td id="T_a76e3_row4_col2" class="data row4 col2" >0.953</td>
#       <td id="T_a76e3_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 20
# <style type="text/css">
# #T_6a0cf_row0_col0, #T_6a0cf_row0_col1, #T_6a0cf_row0_col2, #T_6a0cf_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_6a0cf_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_6a0cf_row1_col0, #T_6a0cf_row1_col1, #T_6a0cf_row1_col2, #T_6a0cf_row3_col3, #T_6a0cf_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_6a0cf_row1_col3, #T_6a0cf_row2_col0, #T_6a0cf_row2_col1, #T_6a0cf_row2_col2, #T_6a0cf_row4_col0, #T_6a0cf_row4_col1, #T_6a0cf_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_6a0cf_row3_col0, #T_6a0cf_row3_col1, #T_6a0cf_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a0cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a0cf_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6a0cf_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6a0cf_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6a0cf_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a0cf_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_6a0cf_row0_col0" class="data row0 col0" >0.951</td>
#       <td id="T_6a0cf_row0_col1" class="data row0 col1" >0.951</td>
#       <td id="T_6a0cf_row0_col2" class="data row0 col2" >0.951</td>
#       <td id="T_6a0cf_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cf_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_6a0cf_row1_col0" class="data row1 col0" >0.967</td>
#       <td id="T_6a0cf_row1_col1" class="data row1 col1" >0.967</td>
#       <td id="T_6a0cf_row1_col2" class="data row1 col2" >0.967</td>
#       <td id="T_6a0cf_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cf_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_6a0cf_row2_col0" class="data row2 col0" >0.961</td>
#       <td id="T_6a0cf_row2_col1" class="data row2 col1" >0.961</td>
#       <td id="T_6a0cf_row2_col2" class="data row2 col2" >0.961</td>
#       <td id="T_6a0cf_row2_col3" class="data row2 col3" >0.961</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cf_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_6a0cf_row3_col0" class="data row3 col0" >0.959</td>
#       <td id="T_6a0cf_row3_col1" class="data row3 col1" >0.959</td>
#       <td id="T_6a0cf_row3_col2" class="data row3 col2" >0.959</td>
#       <td id="T_6a0cf_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_6a0cf_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_6a0cf_row4_col0" class="data row4 col0" >0.961</td>
#       <td id="T_6a0cf_row4_col1" class="data row4 col1" >0.961</td>
#       <td id="T_6a0cf_row4_col2" class="data row4 col2" >0.961</td>
#       <td id="T_6a0cf_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 30
# <style type="text/css">
# #T_6dc7d_row0_col0, #T_6dc7d_row0_col1, #T_6dc7d_row0_col2, #T_6dc7d_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_6dc7d_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_6dc7d_row1_col0, #T_6dc7d_row1_col1, #T_6dc7d_row1_col2, #T_6dc7d_row3_col3, #T_6dc7d_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_6dc7d_row1_col3, #T_6dc7d_row2_col0, #T_6dc7d_row2_col1, #T_6dc7d_row2_col2, #T_6dc7d_row4_col0, #T_6dc7d_row4_col1, #T_6dc7d_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_6dc7d_row3_col0, #T_6dc7d_row3_col1, #T_6dc7d_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6dc7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dc7d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_6dc7d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_6dc7d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_6dc7d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dc7d_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_6dc7d_row0_col0" class="data row0 col0" >0.954</td>
#       <td id="T_6dc7d_row0_col1" class="data row0 col1" >0.955</td>
#       <td id="T_6dc7d_row0_col2" class="data row0 col2" >0.955</td>
#       <td id="T_6dc7d_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_6dc7d_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_6dc7d_row1_col0" class="data row1 col0" >0.970</td>
#       <td id="T_6dc7d_row1_col1" class="data row1 col1" >0.969</td>
#       <td id="T_6dc7d_row1_col2" class="data row1 col2" >0.969</td>
#       <td id="T_6dc7d_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_6dc7d_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_6dc7d_row2_col0" class="data row2 col0" >0.963</td>
#       <td id="T_6dc7d_row2_col1" class="data row2 col1" >0.963</td>
#       <td id="T_6dc7d_row2_col2" class="data row2 col2" >0.963</td>
#       <td id="T_6dc7d_row2_col3" class="data row2 col3" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_6dc7d_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_6dc7d_row3_col0" class="data row3 col0" >0.962</td>
#       <td id="T_6dc7d_row3_col1" class="data row3 col1" >0.962</td>
#       <td id="T_6dc7d_row3_col2" class="data row3 col2" >0.962</td>
#       <td id="T_6dc7d_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_6dc7d_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_6dc7d_row4_col0" class="data row4 col0" >0.963</td>
#       <td id="T_6dc7d_row4_col1" class="data row4 col1" >0.963</td>
#       <td id="T_6dc7d_row4_col2" class="data row4 col2" >0.963</td>
#       <td id="T_6dc7d_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 40
# <style type="text/css">
# #T_c085c_row0_col0, #T_c085c_row0_col1, #T_c085c_row0_col2, #T_c085c_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_c085c_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_c085c_row1_col0, #T_c085c_row1_col1, #T_c085c_row1_col2, #T_c085c_row3_col3, #T_c085c_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_c085c_row1_col3, #T_c085c_row2_col0, #T_c085c_row2_col1, #T_c085c_row2_col2, #T_c085c_row4_col0, #T_c085c_row4_col1, #T_c085c_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_c085c_row3_col0, #T_c085c_row3_col1, #T_c085c_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c085c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c085c_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c085c_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c085c_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c085c_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c085c_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_c085c_row0_col0" class="data row0 col0" >0.954</td>
#       <td id="T_c085c_row0_col1" class="data row0 col1" >0.956</td>
#       <td id="T_c085c_row0_col2" class="data row0 col2" >0.955</td>
#       <td id="T_c085c_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_c085c_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_c085c_row1_col0" class="data row1 col0" >0.970</td>
#       <td id="T_c085c_row1_col1" class="data row1 col1" >0.969</td>
#       <td id="T_c085c_row1_col2" class="data row1 col2" >0.970</td>
#       <td id="T_c085c_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_c085c_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_c085c_row2_col0" class="data row2 col0" >0.964</td>
#       <td id="T_c085c_row2_col1" class="data row2 col1" >0.964</td>
#       <td id="T_c085c_row2_col2" class="data row2 col2" >0.964</td>
#       <td id="T_c085c_row2_col3" class="data row2 col3" >0.964</td>
#     </tr>
#     <tr>
#       <th id="T_c085c_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_c085c_row3_col0" class="data row3 col0" >0.962</td>
#       <td id="T_c085c_row3_col1" class="data row3 col1" >0.963</td>
#       <td id="T_c085c_row3_col2" class="data row3 col2" >0.962</td>
#       <td id="T_c085c_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_c085c_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_c085c_row4_col0" class="data row4 col0" >0.964</td>
#       <td id="T_c085c_row4_col1" class="data row4 col1" >0.964</td>
#       <td id="T_c085c_row4_col2" class="data row4 col2" >0.964</td>
#       <td id="T_c085c_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 50
# <style type="text/css">
# #T_60b42_row0_col0, #T_60b42_row0_col1, #T_60b42_row0_col2, #T_60b42_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_60b42_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_60b42_row1_col0, #T_60b42_row1_col1, #T_60b42_row1_col2, #T_60b42_row3_col3, #T_60b42_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_60b42_row1_col3, #T_60b42_row2_col0, #T_60b42_row2_col1, #T_60b42_row2_col2, #T_60b42_row4_col0, #T_60b42_row4_col1, #T_60b42_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_60b42_row3_col0 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_60b42_row3_col1, #T_60b42_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_60b42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60b42_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_60b42_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_60b42_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_60b42_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60b42_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_60b42_row0_col0" class="data row0 col0" >0.954</td>
#       <td id="T_60b42_row0_col1" class="data row0 col1" >0.960</td>
#       <td id="T_60b42_row0_col2" class="data row0 col2" >0.957</td>
#       <td id="T_60b42_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_60b42_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_60b42_row1_col0" class="data row1 col0" >0.973</td>
#       <td id="T_60b42_row1_col1" class="data row1 col1" >0.969</td>
#       <td id="T_60b42_row1_col2" class="data row1 col2" >0.971</td>
#       <td id="T_60b42_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_60b42_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_60b42_row2_col0" class="data row2 col0" >0.965</td>
#       <td id="T_60b42_row2_col1" class="data row2 col1" >0.965</td>
#       <td id="T_60b42_row2_col2" class="data row2 col2" >0.965</td>
#       <td id="T_60b42_row2_col3" class="data row2 col3" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_60b42_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_60b42_row3_col0" class="data row3 col0" >0.964</td>
#       <td id="T_60b42_row3_col1" class="data row3 col1" >0.964</td>
#       <td id="T_60b42_row3_col2" class="data row3 col2" >0.964</td>
#       <td id="T_60b42_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_60b42_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_60b42_row4_col0" class="data row4 col0" >0.965</td>
#       <td id="T_60b42_row4_col1" class="data row4 col1" >0.965</td>
#       <td id="T_60b42_row4_col2" class="data row4 col2" >0.965</td>
#       <td id="T_60b42_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 60
# <style type="text/css">
# #T_fc680_row0_col0, #T_fc680_row0_col1, #T_fc680_row0_col2, #T_fc680_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_fc680_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_fc680_row1_col0, #T_fc680_row1_col1, #T_fc680_row1_col2, #T_fc680_row3_col3, #T_fc680_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_fc680_row1_col3, #T_fc680_row2_col0, #T_fc680_row2_col1, #T_fc680_row2_col2, #T_fc680_row4_col0, #T_fc680_row4_col1, #T_fc680_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_fc680_row3_col0, #T_fc680_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# #T_fc680_row3_col1 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fc680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc680_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_fc680_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_fc680_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_fc680_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc680_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_fc680_row0_col0" class="data row0 col0" >0.955</td>
#       <td id="T_fc680_row0_col1" class="data row0 col1" >0.963</td>
#       <td id="T_fc680_row0_col2" class="data row0 col2" >0.959</td>
#       <td id="T_fc680_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_fc680_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_fc680_row1_col0" class="data row1 col0" >0.975</td>
#       <td id="T_fc680_row1_col1" class="data row1 col1" >0.970</td>
#       <td id="T_fc680_row1_col2" class="data row1 col2" >0.972</td>
#       <td id="T_fc680_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_fc680_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_fc680_row2_col0" class="data row2 col0" >0.967</td>
#       <td id="T_fc680_row2_col1" class="data row2 col1" >0.967</td>
#       <td id="T_fc680_row2_col2" class="data row2 col2" >0.967</td>
#       <td id="T_fc680_row2_col3" class="data row2 col3" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_fc680_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_fc680_row3_col0" class="data row3 col0" >0.965</td>
#       <td id="T_fc680_row3_col1" class="data row3 col1" >0.966</td>
#       <td id="T_fc680_row3_col2" class="data row3 col2" >0.966</td>
#       <td id="T_fc680_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_fc680_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_fc680_row4_col0" class="data row4 col0" >0.967</td>
#       <td id="T_fc680_row4_col1" class="data row4 col1" >0.967</td>
#       <td id="T_fc680_row4_col2" class="data row4 col2" >0.967</td>
#       <td id="T_fc680_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 70
# <style type="text/css">
# #T_4e64b_row0_col0, #T_4e64b_row0_col1, #T_4e64b_row0_col2, #T_4e64b_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_4e64b_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_4e64b_row1_col0, #T_4e64b_row1_col1, #T_4e64b_row1_col2, #T_4e64b_row3_col3, #T_4e64b_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_4e64b_row1_col3, #T_4e64b_row2_col1, #T_4e64b_row2_col2, #T_4e64b_row4_col0, #T_4e64b_row4_col1, #T_4e64b_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_4e64b_row2_col0 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_4e64b_row3_col0, #T_4e64b_row3_col2 {
#   background-color: #34858d;
#   color: #f1f1f1;
# }
# #T_4e64b_row3_col1 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4e64b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e64b_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4e64b_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4e64b_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4e64b_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e64b_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_4e64b_row0_col0" class="data row0 col0" >0.956</td>
#       <td id="T_4e64b_row0_col1" class="data row0 col1" >0.966</td>
#       <td id="T_4e64b_row0_col2" class="data row0 col2" >0.961</td>
#       <td id="T_4e64b_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e64b_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_4e64b_row1_col0" class="data row1 col0" >0.977</td>
#       <td id="T_4e64b_row1_col1" class="data row1 col1" >0.970</td>
#       <td id="T_4e64b_row1_col2" class="data row1 col2" >0.973</td>
#       <td id="T_4e64b_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e64b_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4e64b_row2_col0" class="data row2 col0" >0.968</td>
#       <td id="T_4e64b_row2_col1" class="data row2 col1" >0.968</td>
#       <td id="T_4e64b_row2_col2" class="data row2 col2" >0.968</td>
#       <td id="T_4e64b_row2_col3" class="data row2 col3" >0.968</td>
#     </tr>
#     <tr>
#       <th id="T_4e64b_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4e64b_row3_col0" class="data row3 col0" >0.966</td>
#       <td id="T_4e64b_row3_col1" class="data row3 col1" >0.968</td>
#       <td id="T_4e64b_row3_col2" class="data row3 col2" >0.967</td>
#       <td id="T_4e64b_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_4e64b_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4e64b_row4_col0" class="data row4 col0" >0.968</td>
#       <td id="T_4e64b_row4_col1" class="data row4 col1" >0.968</td>
#       <td id="T_4e64b_row4_col2" class="data row4 col2" >0.968</td>
#       <td id="T_4e64b_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>
# Resumo da classificação para número de iterações máximas igual a 80
# <style type="text/css">
# #T_b43bc_row0_col0, #T_b43bc_row0_col1, #T_b43bc_row0_col2, #T_b43bc_row2_col3 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_b43bc_row0_col3 {
#   background-color: #44948f;
#   color: #f1f1f1;
# }
# #T_b43bc_row1_col0, #T_b43bc_row1_col1, #T_b43bc_row1_col2, #T_b43bc_row3_col3, #T_b43bc_row4_col3 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_b43bc_row1_col3, #T_b43bc_row2_col1, #T_b43bc_row2_col2, #T_b43bc_row4_col0, #T_b43bc_row4_col1, #T_b43bc_row4_col2 {
#   background-color: #24778b;
#   color: #f1f1f1;
# }
# #T_b43bc_row2_col0 {
#   background-color: #25778c;
#   color: #f1f1f1;
# }
# #T_b43bc_row3_col0, #T_b43bc_row3_col1, #T_b43bc_row3_col2 {
#   background-color: #33858d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b43bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b43bc_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_b43bc_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_b43bc_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_b43bc_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b43bc_level0_row0" class="row_heading level0 row0" >CONFIRMED</th>
#       <td id="T_b43bc_row0_col0" class="data row0 col0" >0.957</td>
#       <td id="T_b43bc_row0_col1" class="data row0 col1" >0.967</td>
#       <td id="T_b43bc_row0_col2" class="data row0 col2" >0.962</td>
#       <td id="T_b43bc_row0_col3" class="data row0 col3" >1047.000</td>
#     </tr>
#     <tr>
#       <th id="T_b43bc_level0_row1" class="row_heading level0 row1" >FALSE POSITIVE</th>
#       <td id="T_b43bc_row1_col0" class="data row1 col0" >0.977</td>
#       <td id="T_b43bc_row1_col1" class="data row1 col1" >0.970</td>
#       <td id="T_b43bc_row1_col2" class="data row1 col2" >0.974</td>
#       <td id="T_b43bc_row1_col3" class="data row1 col3" >1554.000</td>
#     </tr>
#     <tr>
#       <th id="T_b43bc_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_b43bc_row2_col0" class="data row2 col0" >0.969</td>
#       <td id="T_b43bc_row2_col1" class="data row2 col1" >0.969</td>
#       <td id="T_b43bc_row2_col2" class="data row2 col2" >0.969</td>
#       <td id="T_b43bc_row2_col3" class="data row2 col3" >0.969</td>
#     </tr>
#     <tr>
#       <th id="T_b43bc_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_b43bc_row3_col0" class="data row3 col0" >0.967</td>
#       <td id="T_b43bc_row3_col1" class="data row3 col1" >0.968</td>
#       <td id="T_b43bc_row3_col2" class="data row3 col2" >0.968</td>
#       <td id="T_b43bc_row3_col3" class="data row3 col3" >2601.000</td>
#     </tr>
#     <tr>
#       <th id="T_b43bc_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_b43bc_row4_col0" class="data row4 col0" >0.969</td>
#       <td id="T_b43bc_row4_col1" class="data row4 col1" >0.969</td>
#       <td id="T_b43bc_row4_col2" class="data row4 col2" >0.969</td>
#       <td id="T_b43bc_row4_col3" class="data row4 col3" >2601.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Matriz de Confusão

# %%
for i in range(len(dfResumosClassificacao)):
    print("Matriz de confusão para número de iterações máximas igual a", numerosIteracoes[i])
    
    # Obtem a matriz de confusão
    confusionMatrix = confusion_matrix(y_test, y_preds[i])

    # Desenha a matriz de confusão
    plt.figure(figsize=(3, 3))
    sns.heatmap(confusionMatrix, annot=True, fmt=".1f", cmap=STYLE)
    plt.title('Matriz de Confusão')
    plt.xlabel('Rótulo Falso Verdadeiro')
    plt.ylabel('Rótulo Verdadeiro')
    plt.grid(False)
    plt.show()

    totalRotulos = X_test.shape[0]
    corretamenteRotulados = (y_test == y_preds[i]).sum()
    incorretamenteRotulados = (y_test != y_preds[i]).sum()

    print("Número de pontos corretamente rotulados de um total de", totalRotulos, "pontos:", corretamenteRotulados, "(", round((corretamenteRotulados / totalRotulos) * 100), "%)")
    print("Número de pontos incorretamente rotulados de um total de", totalRotulos, "pontos:", incorretamenteRotulados, "(", round((incorretamenteRotulados / totalRotulos) * 100), "%) \n")
# Out:
# Matriz de confusão para número de iterações máximas igual a 10
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2480 ( 95 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 121 ( 5 %)
#
# Matriz de confusão para número de iterações máximas igual a 20
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2499 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 102 ( 4 %)
#
# Matriz de confusão para número de iterações máximas igual a 30
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2506 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 95 ( 4 %)
#
# Matriz de confusão para número de iterações máximas igual a 40
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2507 ( 96 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 94 ( 4 %)
#
# Matriz de confusão para número de iterações máximas igual a 50
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2511 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 90 ( 3 %)
#
# Matriz de confusão para número de iterações máximas igual a 60
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2515 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 86 ( 3 %)
#
# Matriz de confusão para número de iterações máximas igual a 70
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2518 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 83 ( 3 %)
#
# Matriz de confusão para número de iterações máximas igual a 80
# Número de pontos corretamente rotulados de um total de 2601 pontos: 2520 ( 97 %)
# Número de pontos incorretamente rotulados de um total de 2601 pontos: 81 ( 3 %)

# %% [markdown]
# ### Acurácia e Validação Cruzada K-fold¶

# %%
dfResultadosAcuracia = pd.DataFrame({
'Acurácia': acuracias
}, index = numerosIteracoes)

mediasValidacoesCruzadas = [np.mean(k5Values) for k5Values in validacoesCruzadas]
dfResultadosValidacaoCruzada = pd.DataFrame({
'Validação Cruzada (média)': mediasValidacoesCruzadas
}, index = numerosIteracoes)


dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df
dfResultadosValidacaoCruzadaEstilizada = dfResultadosValidacaoCruzada.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

display(dfResultadosAcuraciaEstilizada)
display(dfResultadosValidacaoCruzadaEstilizada)
# Out:
# <style type="text/css">
# #T_9db55_row0_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_9db55_row1_col0 {
#   background-color: #38898e;
#   color: #f1f1f1;
# }
# #T_9db55_row2_col0 {
#   background-color: #1e6e8a;
#   color: #f1f1f1;
# }
# #T_9db55_row3_col0 {
#   background-color: #1d6a8a;
#   color: #f1f1f1;
# }
# #T_9db55_row4_col0 {
#   background-color: #1f5985;
#   color: #f1f1f1;
# }
# #T_9db55_row5_col0 {
#   background-color: #27477d;
#   color: #f1f1f1;
# }
# #T_9db55_row6_col0 {
#   background-color: #2b3a76;
#   color: #f1f1f1;
# }
# #T_9db55_row7_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9db55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9db55_level0_col0" class="col_heading level0 col0" >Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9db55_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_9db55_row0_col0" class="data row0 col0" >0.953</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_9db55_row1_col0" class="data row1 col0" >0.961</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_9db55_row2_col0" class="data row2 col0" >0.963</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_9db55_row3_col0" class="data row3 col0" >0.964</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_9db55_row4_col0" class="data row4 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_9db55_row5_col0" class="data row5 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_9db55_row6_col0" class="data row6 col0" >0.968</td>
#     </tr>
#     <tr>
#       <th id="T_9db55_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_9db55_row7_col0" class="data row7 col0" >0.969</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_112b9_row0_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_112b9_row1_col0 {
#   background-color: #2a7c8c;
#   color: #f1f1f1;
# }
# #T_112b9_row2_col0 {
#   background-color: #21738b;
#   color: #f1f1f1;
# }
# #T_112b9_row3_col0 {
#   background-color: #205684;
#   color: #f1f1f1;
# }
# #T_112b9_row4_col0 {
#   background-color: #1e5b86;
#   color: #f1f1f1;
# }
# #T_112b9_row5_col0 {
#   background-color: #27477d;
#   color: #f1f1f1;
# }
# #T_112b9_row6_col0 {
#   background-color: #2b3674;
#   color: #f1f1f1;
# }
# #T_112b9_row7_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_112b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_112b9_level0_col0" class="col_heading level0 col0" >Validação Cruzada (média)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_112b9_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_112b9_row0_col0" class="data row0 col0" >0.954</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_112b9_row1_col0" class="data row1 col0" >0.962</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row2" class="row_heading level0 row2" >30</th>
#       <td id="T_112b9_row2_col0" class="data row2 col0" >0.962</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row3" class="row_heading level0 row3" >40</th>
#       <td id="T_112b9_row3_col0" class="data row3 col0" >0.965</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_112b9_row4_col0" class="data row4 col0" >0.964</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row5" class="row_heading level0 row5" >60</th>
#       <td id="T_112b9_row5_col0" class="data row5 col0" >0.966</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row6" class="row_heading level0 row6" >70</th>
#       <td id="T_112b9_row6_col0" class="data row6 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_112b9_level0_row7" class="row_heading level0 row7" >80</th>
#       <td id="T_112b9_row7_col0" class="data row7 col0" >0.967</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparação da Acurácia e Validação Cruzada K-fold¶

# %%
plt.plot(numerosIteracoes, acuracias, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Acurácia')
plt.title('Variação da Acurácia em relação ao Número de Árvores')
plt.grid(False)
plt.show()

plt.plot(numerosIteracoes, validacoesCruzadas, marker='s')
plt.xlabel('Número de Árvores')
plt.ylabel('Validação Cruzada')
plt.title('Variação da Validação Cruzada em relação ao Número de Árvores')
plt.grid(False)
plt.show()

# %% [markdown]
# ### Inferência Sobre os Resultados

# %% [markdown]
# # Resultados Finais

# %% [markdown]
# Nesta etapa final, após armazenar os resultados dos experimentos de cada algoritmo que alcançou a melhor acurácia, já temos dados prontos para apresentar uma conclusão.

# %% [markdown]
# ## Graficos de Resultados Finais

# %% [markdown]
# Os testes realizados utilizando os métodos propostos nos forneceram uma valiosa oportunidade de avaliar o desempenho desses algoritmos de classificaçãos. Por meio desses testes, foram gerados os seguintes gráficos, que nos ajudarão a interpretar os resultados obtidos.

# %% [markdown]
# ### Acurácias

# %%
dfResultadosAcuracia = pd.DataFrame({
    'Melhor Acurácia': melhoresAcuracias
}, index = metodosTestados)

dfResultadosAcuraciaEstilizada = dfResultadosAcuracia.style.background_gradient(cmap=STYLE).format("{:.3f}") # Estiliza meu df

print("Melhor acurácia obtida nos experimentos de cada método")
display(dfResultadosAcuraciaEstilizada)
# Out:
# Melhor acurácia obtida nos experimentos de cada método
# <style type="text/css">
# #T_69620_row0_col0 {
#   background-color: #91c391;
#   color: #000000;
# }
# #T_69620_row1_col0 {
#   background-color: #244e81;
#   color: #f1f1f1;
# }
# #T_69620_row2_col0 {
#   background-color: #254a7f;
#   color: #f1f1f1;
# }
# #T_69620_row3_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_69620_row4_col0 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# #T_69620_row5_col0 {
#   background-color: #2c3373;
#   color: #f1f1f1;
# }
# #T_69620_row6_col0 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_69620">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69620_level0_col0" class="col_heading level0 col0" >Melhor Acurácia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69620_level0_row0" class="row_heading level0 row0" >NB</th>
#       <td id="T_69620_row0_col0" class="data row0 col0" >0.790</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row1" class="row_heading level0 row1" >DT</th>
#       <td id="T_69620_row1_col0" class="data row1 col0" >0.937</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row2" class="row_heading level0 row2" >SVML</th>
#       <td id="T_69620_row2_col0" class="data row2 col0" >0.942</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row3" class="row_heading level0 row3" >SVMR</th>
#       <td id="T_69620_row3_col0" class="data row3 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row4" class="row_heading level0 row4" >k-NN</th>
#       <td id="T_69620_row4_col0" class="data row4 col0" >0.776</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row5" class="row_heading level0 row5" >RF</th>
#       <td id="T_69620_row5_col0" class="data row5 col0" >0.967</td>
#     </tr>
#     <tr>
#       <th id="T_69620_level0_row6" class="row_heading level0 row6" >GTB</th>
#       <td id="T_69620_row6_col0" class="data row6 col0" >0.969</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comparação de Acurácias

# %%
plt.plot(metodosTestados, melhoresAcuracias, marker='s')
plt.xlabel('Métodos')
plt.ylabel('Acurácia')
plt.title('Acurácia em relação aos Experimentos')
plt.grid(False)
plt.show()

# %% [markdown]
# ## Inferência Final
